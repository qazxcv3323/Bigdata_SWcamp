# %%
path = 'C:/Users/DMC CONET/Desktop/data/csv_데이터'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

import seaborn as sns

# %%
from glob import glob

# %%
file_list = sorted(glob(path + "/*.csv"))
file_list
# Out:
# ['C:/Users/DMC CONET/Desktop/data/csv_데이터\\google_patent.csv',
#  'C:/Users/DMC CONET/Desktop/data/csv_데이터\\jobplanet_review.csv',
#  'C:/Users/DMC CONET/Desktop/data/csv_데이터\\kipris_design.csv',
#  'C:/Users/DMC CONET/Desktop/data/csv_데이터\\kipris_family.csv',
#  'C:/Users/DMC CONET/Desktop/data/csv_데이터\\kipris_mark.csv',
#  'C:/Users/DMC CONET/Desktop/data/csv_데이터\\kipris_utility.csv',
#  'C:/Users/DMC CONET/Desktop/data/csv_데이터\\kisti_patent.csv',
#  'C:/Users/DMC CONET/Desktop/data/csv_데이터\\naver_news.csv',
#  'C:/Users/DMC CONET/Desktop/data/csv_데이터\\ntis_assign.csv']

# %%
file_data_list = []
for filename in file_list:
    file_data_list.append(pd.read_csv(filename, encoding = 'utf-8'))
file_data = pd.concat(file_data_list, keys = '사업자등록번호', ignore_index = False)
# Out:
# C:\Users\DMC CONET\AppData\Local\Temp\ipykernel_20712\2699988400.py:3: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_data_list.append(pd.read_csv(filename, encoding = 'utf-8'))
# C:\Users\DMC CONET\AppData\Local\Temp\ipykernel_20712\2699988400.py:3: DtypeWarning: Columns (10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_data_list.append(pd.read_csv(filename, encoding = 'utf-8'))
# C:\Users\DMC CONET\AppData\Local\Temp\ipykernel_20712\2699988400.py:3: DtypeWarning: Columns (3,42,44,46,48,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   file_data_list.append(pd.read_csv(filename, encoding = 'utf-8'))

# %%
pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
file_data.shape
# Out:
# (1027245, 76)

# %%
(file_data.isnull().sum() / 1027245) * 100
# Out:
# 사업자등록번호          0.000000
# 순번               0.000000
# 데이터수집일자         13.649032
# 출원번호            41.460703
# 특허명             84.775589
# 출원날짜            84.775492
# CPC번호           85.675569
# 인용수             94.947749
# 피인용수            97.433816
# 발명자수            84.775492
# 청구항수            84.836237
# 작업구분코드           0.000000
# 데이터생성일자          0.000000
# 연계처리상태코드       100.000000
# 연계처리일자         100.000000
# 직군명             96.977157
# 직원여부분류명         96.851773
# 댓글작성년월          97.151118
# 종합점수            96.851287
# 승진기회점수          96.851287
# 복지및급여점수         96.851287
# 업무생명균형점수        96.851287
# 기업문화점수          96.851287
# 경영진점수           96.851287
# 취업사이트댓글제목       96.851287
# 기업장점설명          96.851287
# 기업단점설명          96.851287
# 경영진요청사항설명       96.852065
# 기업성장가능성설명       97.939148
# 기업추천여부설명        97.556279
# 대리인             85.128961
# 출원잠조번호          99.998150
# 출원인명            56.677618
# 출원일자            56.683362
# 출원상태            81.935371
# ...

# %%
df_cri = pd.read_excel(path + "/데이터제공목록.xlsx", sheet_name = "제공목록")
df_cri
# Out:
#        Unnamed: 0       사업자번호           기업명 CRI등급  \
# 0               0  1000861574          성진섬유    C2
# 1               1  1010117344            썬텔     D
# 2               2  1010134270          한국과학    C2
# 3               3  1010157569           윤석조    C1
# 4               4  1010165297         드림오피스    B2
# ...           ...         ...           ...   ...
# 44241       44241  8998801372            포스    C3
# 44242       44242  8998801673            리코    C2
# 44243       44243  9068126629       태정산업(주)    C1
# 44244       44244  9158206034  한국조선해양기자재연구원    C1
# 44245       44245  9876543210          한국기업    C2
#
#        * 추출기준: 교집합( 합집합(kisti_patent, ntis_assign),  ntis_cri)
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...

# %%
df_cri = df_cri.drop('Unnamed: 0', axis = 1)
df_cri
# Out:
#             사업자번호           기업명 CRI등급  \
# 0      1000861574          성진섬유    C2
# 1      1010117344            썬텔     D
# 2      1010134270          한국과학    C2
# 3      1010157569           윤석조    C1
# 4      1010165297         드림오피스    B2
# ...           ...           ...   ...
# 44241  8998801372            포스    C3
# 44242  8998801673            리코    C2
# 44243  9068126629       태정산업(주)    C1
# 44244  9158206034  한국조선해양기자재연구원    C1
# 44245  9876543210          한국기업    C2
#
#        * 추출기준: 교집합( 합집합(kisti_patent, ntis_assign),  ntis_cri)
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44241                                                NaN
# ...

# %%
df_cri = df_cri[['사업자번호', '기업명', 'CRI등급']]
df_cri['사업자등록번호'] = df_cri['사업자번호']

# %%
df_f = pd.merge(file_data, df_cri, how = 'outer', on = ['사업자등록번호'])
df_f.columns
# Out:
# Index(['사업자등록번호', '순번', '데이터수집일자', '출원번호', '특허명', '출원날짜', 'CPC번호', '인용수',
#        '피인용수', '발명자수', '청구항수', '작업구분코드', '데이터생성일자', '연계처리상태코드', '연계처리일자',
#        '직군명', '직원여부분류명', '댓글작성년월', '종합점수', '승진기회점수', '복지및급여점수', '업무생명균형점수',
#        '기업문화점수', '경영진점수', '취업사이트댓글제목', '기업장점설명', '기업단점설명', '경영진요청사항설명',
#        '기업성장가능성설명', '기업추천여부설명', '대리인', '출원잠조번호', '출원인명', '출원일자', '출원상태',
#        '물품명칭', '디자인분류', '디자인번호', '형태분류', '국제등록일자', '국제등록번호', '창작자명', '공개일자',
#        '공개번호', '우선권주장일자', '우선권주장번호', '공고일자', '공고번호', '등록참조번호', '등록일자', '등록번호',
#        '국내출원번호', 'DOCDB패밀리ID', 'DOCDB출원국가코드', 'DOCDB출원일자', 'DOCDB출원종류코드',
#        'DOCDB출원번호', 'DOCDB공보국가코드', 'DOCDB공보일자', 'DOCDB공보종류코드', 'DOCDB공보번호',
#        '상품분류코드', '등록권자', '상표권명칭', '도형코드', '초록', '발명명칭', 'IPC코드내용', '등록상태',
#        '특허명칭', '국가코드', '국가코드명', '특허법적상태', '국문발명자명칭', '영문발명자명칭', 'NDSL상세보기URL',
#        '사업자번호', '기업명', 'CRI등급'],
#       dtype='object')

# %%
df_f.shape
# Out:
# (1027245, 79)

# %%
(df_f.isnull().sum() / 1027245) * 100
# Out:
# 사업자등록번호          0.000000
# 순번               0.000000
# 데이터수집일자         13.649032
# 출원번호            41.460703
# 특허명             84.775589
# 출원날짜            84.775492
# CPC번호           85.675569
# 인용수             94.947749
# 피인용수            97.433816
# 발명자수            84.775492
# 청구항수            84.836237
# 작업구분코드           0.000000
# 데이터생성일자          0.000000
# 연계처리상태코드       100.000000
# 연계처리일자         100.000000
# 직군명             96.977157
# 직원여부분류명         96.851773
# 댓글작성년월          97.151118
# 종합점수            96.851287
# 승진기회점수          96.851287
# 복지및급여점수         96.851287
# 업무생명균형점수        96.851287
# 기업문화점수          96.851287
# 경영진점수           96.851287
# 취업사이트댓글제목       96.851287
# 기업장점설명          96.851287
# 기업단점설명          96.851287
# 경영진요청사항설명       96.852065
# 기업성장가능성설명       97.939148
# 기업추천여부설명        97.556279
# 대리인             85.128961
# 출원잠조번호          99.998150
# 출원인명            56.677618
# 출원일자            56.683362
# 출원상태            81.935371
# ...

# %%
df_f.describe(include = 'object')
# Out:
#                    출원번호     특허명      CPC번호   작업구분코드    직군명 직원여부분류명  \
# count            601342  156392     147147  1027245  31052   32340
# unique           267726   62958      23222        1     22      29
# top     10-2021-0015867  파력발생장치  G06Q50/10        I  IT인터넷     전직원
# freq                101     108       1611  1027245  11761   22220
#
#                                   취업사이트댓글제목                           기업장점설명  \
# count                                 32345                            32345
# unique                                29632                            29674
# top     회사 분위기 좋음 일도 할만하고 사람들도 친절하시고 잘 대해주심  분위기가 좋고 업무 중 쉬는시간 있음 개인적인 시간 보장
# freq                                     26                               26
#
#                                   기업단점설명                         경영진요청사항설명  \
# count                              32345                             32337
# unique                             29691                             29613
# ...

# %% [markdown]
# df_f.to_csv("final_data_20221129.csv", encoding = "cp949")

# %%
df_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1027245 entries, 0 to 1027244
# Data columns (total 79 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   사업자등록번호      1027245 non-null  int64
#  1   순번           1027245 non-null  int64
#  2   데이터수집일자      887036 non-null   float64
#  3   출원번호         601342 non-null   object
#  4   특허명          156392 non-null   object
#  5   출원날짜         156393 non-null   float64
#  6   CPC번호        147147 non-null   object
#  7   인용수          51899 non-null    float64
#  8   피인용수         26361 non-null    float64
#  9   발명자수         156393 non-null   float64
#  10  청구항수         155769 non-null   float64
#  11  작업구분코드       1027245 non-null  object
#  12  데이터생성일자      1027245 non-null  int64
#  13  연계처리상태코드     0 non-null        float64
#  14  연계처리일자       0 non-null        float64
#  15  직군명          31052 non-null    object
#  16  직원여부분류명      32340 non-null    object
# ...

# %%
df_f_desc = df_f.describe().T
df_f_desc

df_f_desc['IQR'] = df_f_desc['75%'] - df_f_desc['25%']
df_f_desc
# Out:
#                 count          mean           std           min           25%  \
# 사업자등록번호     1027245.0  3.618432e+09  2.228623e+09  1.000862e+09  1.378509e+09
# 순번          1027245.0  6.542185e+00  5.826706e+00  1.000000e+00  1.000000e+00
# 데이터수집일자      887036.0  2.021999e+07  2.326832e+03  2.021062e+07  2.022051e+07
# 출원날짜         156393.0  2.010129e+07  7.493136e+04  1.977031e+07  2.005041e+07
# 인용수           51899.0  1.982177e+00  1.614468e+00  1.000000e+00  1.000000e+00
# 피인용수          26361.0  2.162399e+00  3.923896e+00  1.000000e+00  1.000000e+00
# 발명자수         156393.0  1.818572e+00  1.508782e+00  1.000000e+00  1.000000e+00
# 청구항수         155769.0  5.291053e+00  4.638083e+00  1.000000e+00  2.000000e+00
# 데이터생성일자     1027245.0  2.022112e+07  0.000000e+00  2.022112e+07  2.022112e+07
# 연계처리상태코드          0.0           NaN           NaN           NaN           NaN
# 연계처리일자            0.0           NaN           NaN           NaN           NaN
# ...

# %%
df_f_desc_max = df_f_desc['25%'] + (df_f_desc['IQR'] * 1.5)
df_f_desc_max = pd.DataFrame(df_f_desc_max)
df_f_desc_min = df_f_desc['25%'] - (df_f_desc['IQR'] * 1.5)
df_f_desc_min = pd.DataFrame(df_f_desc_min)

print(df_f_desc_max)
print(df_f_desc_min)
# Out:
#                        0
# 사업자등록번호     7.123798e+09
# 순번          1.600000e+01
# 데이터수집일자     2.022054e+07
# 출원날짜        2.021617e+07
# 인용수         4.000000e+00
# 피인용수        2.500000e+00
# 발명자수        2.500000e+00
# 청구항수        9.500000e+00
# 데이터생성일자     2.022112e+07
# 연계처리상태코드             NaN
# 연계처리일자               NaN
# 댓글작성년월      2.022050e+05
# 종합점수        8.000000e+01
# 승진기회점수      8.000000e+01
# 복지및급여점수     8.000000e+01
# 업무생명균형점수    1.100000e+02
# 기업문화점수      8.000000e+01
# 경영진점수       8.000000e+01
# 출원잠조번호      3.020195e+12
# 출원일자        2.026105e+07
# 국제등록일자      2.018103e+07
# 공개일자        2.028152e+07
# 우선권주장일자     2.000536e+07
# 공고일자        2.027031e+07
# 등록참조번호      3.010622e+12
# 등록일자        2.027030e+07
# 국내출원번호      4.019930e+12
# DOCDB패밀리ID  7.080486e+07
# DOCDB출원일자   2.022088e+07
# DOCDB공보일자   2.024023e+07
# 상품분류코드      5.100000e+01
# 도형코드        3.703575e+05
# 사업자번호       7.123798e+09
#                        0
# 사업자등록번호    -4.366781e+09
# 순번         -1.400000e+01
# ...

# %%
df_f_desc_max
# Out:
#                        0
# 사업자등록번호     7.123798e+09
# 순번          1.600000e+01
# 데이터수집일자     2.022054e+07
# 출원날짜        2.021617e+07
# 인용수         4.000000e+00
# 피인용수        2.500000e+00
# 발명자수        2.500000e+00
# 청구항수        9.500000e+00
# 데이터생성일자     2.022112e+07
# 연계처리상태코드             NaN
# 연계처리일자               NaN
# 댓글작성년월      2.022050e+05
# 종합점수        8.000000e+01
# 승진기회점수      8.000000e+01
# 복지및급여점수     8.000000e+01
# 업무생명균형점수    1.100000e+02
# 기업문화점수      8.000000e+01
# 경영진점수       8.000000e+01
# 출원잠조번호      3.020195e+12
# 출원일자        2.026105e+07
# 국제등록일자      2.018103e+07
# 공개일자        2.028152e+07
# 우선권주장일자     2.000536e+07
# 공고일자        2.027031e+07
# 등록참조번호      3.010622e+12
# 등록일자        2.027030e+07
# 국내출원번호      4.019930e+12
# DOCDB패밀리ID  7.080486e+07
# DOCDB출원일자   2.022088e+07
# DOCDB공보일자   2.024023e+07
# 상품분류코드      5.100000e+01
# 도형코드        3.703575e+05
# 사업자번호       7.123798e+09

# %% [markdown]
# #### 수치형 데이터

# %%
df_f[['인용수', #'피인용수', 
      '발명자수', '청구항수', '종합점수', '승진기회점수', '복지및급여점수', '업무생명균형점수', '기업문화점수', '경영진점수']]
# Out:
#          인용수  발명자수  청구항수  종합점수  승진기회점수  복지및급여점수  업무생명균형점수  기업문화점수  경영진점수
# 0        NaN   NaN   NaN   NaN     NaN      NaN       NaN     NaN    NaN
# 1        NaN   NaN   NaN   NaN     NaN      NaN       NaN     NaN    NaN
# 2        NaN   NaN   NaN   NaN     NaN      NaN       NaN     NaN    NaN
# 3        NaN   NaN   NaN   NaN     NaN      NaN       NaN     NaN    NaN
# 4        NaN   NaN   NaN   NaN     NaN      NaN       NaN     NaN    NaN
# ...      ...   ...   ...   ...     ...      ...       ...     ...    ...
# 1027240  NaN   NaN   NaN   NaN     NaN      NaN       NaN     NaN    NaN
# 1027241  NaN   NaN   NaN   NaN     NaN      NaN       NaN     NaN    NaN
# 1027242  NaN   NaN   NaN   NaN     NaN      NaN       NaN     NaN    NaN
# 1027243  NaN   NaN   NaN   NaN     NaN      NaN       NaN     NaN    NaN
# 1027244  NaN   NaN   NaN   NaN     NaN      NaN       NaN     NaN    NaN
#
# [1027245 rows x 9 columns]

# %%
df_f_citation = df_f.loc[~df_f['인용수'].isnull()]
df_f_citation
# Out:
#             사업자등록번호  순번     데이터수집일자             출원번호  \
# 21       1010117344  10  20220512.0  1020080072104.0
# 23       1010117344  12  20220512.0  1020080092106.0
# 147      1010165297   5  20220512.0  1020160024502.0
# 148      1010165297   6  20220512.0  1020160153441.0
# 149      1010165297   7  20220512.0  1020160153442.0
# ...             ...  ..         ...              ...
# 1026972  8998701827  20  20220603.0  1020090104925.0
# 1027058  8998800811   1  20220603.0  1020190052727.0
# 1027059  8998800811   2  20220603.0  1020200079829.0
# 1027060  8998800811   3  20220603.0  1020200083705.0
# 1027061  8998800811   4  20220603.0  1020200083300.0
#
#                                                        특허명        출원날짜  \
# 21             연료전지용 촉매 담지체, 촉매, 막전극접합체, 연료전지 및촉매 담지체 제조방법  20080724.0
# 23                              소섬경 플레이트리트 탄소나노섬유 및 그 제조방법  20080919.0
# 147                        터치펜 팁 및 펜슬심 깎기용 펜슬 뚜껑을 구비한 터치펜슬  20160229.0
# ...

# %%
df_f_citation.isnull().sum()
# Out:
# 사업자등록번호            0
# 순번                 0
# 데이터수집일자            0
# 출원번호               0
# 특허명                0
# 출원날짜               0
# CPC번호            270
# 인용수                0
# 피인용수           38173
# 발명자수               0
# 청구항수             150
# 작업구분코드             0
# 데이터생성일자            0
# 연계처리상태코드       51899
# 연계처리일자         51899
# 직군명            51899
# 직원여부분류명        51899
# 댓글작성년월         51899
# 종합점수           51899
# 승진기회점수         51899
# 복지및급여점수        51899
# 업무생명균형점수       51899
# 기업문화점수         51899
# 경영진점수          51899
# 취업사이트댓글제목      51899
# 기업장점설명         51899
# 기업단점설명         51899
# 경영진요청사항설명      51899
# 기업성장가능성설명      51899
# 기업추천여부설명       51899
# 대리인            51899
# 출원잠조번호         51899
# 출원인명           51899
# 출원일자           51899
# 출원상태           51899
# 물품명칭           51899
# 디자인분류          51899
# 디자인번호          51899
# 형태분류           51899
# 국제등록일자         51899
# 국제등록번호         51899
# 창작자명           51899
# 공개일자           51899
# ...

# %%
df_f.loc[~df_f['승진기회점수'].isnull()]
# Out:
#             사업자등록번호  순번     데이터수집일자 출원번호  특허명  출원날짜 CPC번호  인용수  피인용수  발명자수  \
# 327      1010299794   1  20210918.0  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 367      1010335064   1  20210918.0  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 368      1010335064   2  20210918.0  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 369      1010335064   3  20210918.0  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 370      1010335064   4  20210918.0  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# ...             ...  ..         ...  ...  ...   ...   ...  ...   ...   ...
# 1024153  8918100292  18  20210917.0  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 1024154  8918100292  19  20210917.0  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 1026667  8988700562   1  20210917.0  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 1026668  8988700562   2  20210917.0  NaN  NaN   NaN   NaN  NaN   NaN   NaN
# 1026669  8988700562   3  20210917.0  NaN  NaN   NaN   NaN  NaN   NaN   NaN
#
# ...

# %%
df_f_patents = df_f.loc[~df_f['특허명'].isnull()]
df_f_patents
# Out:
#             사업자등록번호  순번     데이터수집일자             출원번호                    특허명  \
# 12       1010117344   1  20220512.0  1020050003815.0               키패드 제조공정
# 13       1010117344   2  20220512.0  2020050003011.0        일체형 휴대폰 키패드의 구조
# 14       1010117344   3  20220512.0  1020050031809.0        케이스일체형키패드의 제조방법
# 15       1010117344   4  20220512.0  1020050034434.0               키패드 제조방법
# 16       1010117344   5  20220512.0  1020060114187.0                    키패드
# ...             ...  ..         ...              ...                    ...
# 1027123  9068126629   5  20220603.0  1020050008439.0  글라스울 및 미네랄울의 자동적재 시스템
# 1027124  9068126629   6  20220603.0  2020060026715.0     자동차 배선용 컨넥터 와이어 시일
# 1027125  9068126629   7  20220603.0  1020110085517.0   프레스 연동 자동 프로젝션 용접 장치
# 1027126  9068126629   8  20220603.0  1020120103694.0               가공물 검사장치
# 1027127  9068126629   9  20220603.0  1020120103695.0           자동 프로젝션 용접장치
#
# ...

# %%
df_f_patents.describe(include = 'all')
# Out:
#              사업자등록번호             순번       데이터수집일자          출원번호     특허명  \
# count   1.563920e+05  156392.000000  1.563920e+05  1.563920e+05  156392
# unique           NaN            NaN           NaN  6.748200e+04   62958
# top              NaN            NaN           NaN  1.020190e+12  파력발생장치
# freq             NaN            NaN           NaN  7.600000e+01     108
# mean    3.560013e+09       7.715088  2.022051e+07           NaN     NaN
# std     2.201378e+09       5.591246  3.050626e+01           NaN     NaN
# min     1.010117e+09       1.000000  2.022043e+07           NaN     NaN
# 25%     1.358148e+09       3.000000  2.022051e+07           NaN     NaN
# 50%     3.110254e+09       6.000000  2.022052e+07           NaN     NaN
# 75%     5.142486e+09      12.000000  2.022053e+07           NaN     NaN
# max     9.068127e+09      20.000000  2.022060e+07           NaN     NaN
#
#                 출원날짜      CPC번호           인용수          피인용수           발명자수  \
# ...

# %%
(df_f_patents.isnull().sum() / 156392) * 100
# Out:
# 사업자등록번호          0.000000
# 순번               0.000000
# 데이터수집일자          0.000000
# 출원번호             0.000000
# 특허명              0.000000
# 출원날짜             0.000000
# CPC번호            5.912067
# 인용수             66.814799
# 피인용수            83.144278
# 발명자수             0.000000
# 청구항수             0.398997
# 작업구분코드           0.000000
# 데이터생성일자          0.000000
# 연계처리상태코드       100.000000
# 연계처리일자         100.000000
# 직군명            100.000000
# 직원여부분류명        100.000000
# 댓글작성년월         100.000000
# 종합점수           100.000000
# 승진기회점수         100.000000
# 복지및급여점수        100.000000
# 업무생명균형점수       100.000000
# 기업문화점수         100.000000
# 경영진점수          100.000000
# 취업사이트댓글제목      100.000000
# 기업장점설명         100.000000
# 기업단점설명         100.000000
# 경영진요청사항설명      100.000000
# 기업성장가능성설명      100.000000
# 기업추천여부설명       100.000000
# 대리인            100.000000
# 출원잠조번호         100.000000
# 출원인명           100.000000
# 출원일자           100.000000
# 출원상태           100.000000
# ...

# %%
X = df_f_patents[['데이터수집일자', '특허명', 'CPC번호', '인용수', '피인용수', '발명자수', '청구항수', '작업구분코드', '기업명', 'CRI등급']]

# %%
X_desc = X.describe()
X_desc
# Out:
#             데이터수집일자           인용수          피인용수           발명자수           청구항수
# count  1.563920e+05  51899.000000  26361.000000  156392.000000  155768.000000
# mean   2.022051e+07      1.982177      2.162399       1.818565       5.291061
# std    3.050626e+01      1.614468      3.923896       1.508783       4.638096
# min    2.022043e+07      1.000000      1.000000       1.000000       1.000000
# 25%    2.022051e+07      1.000000      1.000000       1.000000       2.000000
# 50%    2.022052e+07      2.000000      1.000000       1.000000       4.000000
# 75%    2.022053e+07      3.000000      2.000000       2.000000       7.000000
# max    2.022060e+07    104.000000    199.000000      39.000000     159.000000

# %%
sns.distplot(df_f_patents['인용수'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='인용수', ylabel='Density'>
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 50857 (\N{HANGUL SYLLABLE YONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
# ...

# %%
X
# Out:
#             데이터수집일자                    특허명        CPC번호  인용수  피인용수  발명자수  \
# 12       20220512.0               키패드 제조공정    H01H13/88  NaN  23.0   1.0
# 13       20220512.0        일체형 휴대폰 키패드의 구조    H04M1/233  NaN   NaN   1.0
# 14       20220512.0        케이스일체형키패드의 제조방법    H01H13/88  NaN   NaN   1.0
# 15       20220512.0               키패드 제조방법   A61H33/066  NaN   NaN   1.0
# 16       20220512.0                    키패드    H01H13/48  NaN   NaN   2.0
# ...             ...                    ...          ...  ...   ...   ...
# 1027123  20220603.0  글라스울 및 미네랄울의 자동적재 시스템  A61H15/0078  NaN   NaN   1.0
# 1027124  20220603.0     자동차 배선용 컨넥터 와이어 시일  H01R13/5205  NaN   NaN   1.0
# 1027125  20220603.0   프레스 연동 자동 프로젝션 용접 장치    B23K11/14  NaN   NaN   1.0
# 1027126  20220603.0               가공물 검사장치    B23K11/34  NaN   NaN   1.0
# 1027127  20220603.0           자동 프로젝션 용접장치    B23K11/14  NaN   NaN   1.0
#
#          청구항수 작업구분코드      기업명 CRI등급
# 12        6.0      I       썬텔     D
# ...

# %%
X1 = X.dropna()
X1
# Out:
#             데이터수집일자                                                특허명  \
# 293      20220512.0                                휴대 단말기의 다이어리형 보호케이스
# 366      20220512.0  적외선 카메라와 객체 추적이 가능한 성범죄자 데이터베이스와 연동되는 지능형 비상벨 시스템
# 393      20220512.0           보안성을 강화한 안티 엘리어싱 기반의 폰트 표시방법 및 폰트 표시 시스템
# 395      20220512.0                     그리드 컴퓨팅 시스템 및 그리드 컴퓨팅 서비스 제공방법
# 494      20220512.0                                 노면표시용 문자 도색장치 및 방법
# ...             ...                                                ...
# 1026213  20220603.0                 지엔에스에스를 이용한 크레인 충돌방지 모니터링 시스템 및 방법
# 1026219  20220603.0                       모바일 단말을 이용한 gnss 측량 시스템 및 방법
# 1026291  20220603.0                                 강관파일을 이용한 흙막이 시공방법
# 1026502  20220603.0                                           지능형 트레일러
# 1027058  20220603.0                        인공지능 기반 악성 도메인 분류 방법 및 프로그램
#
#                 CPC번호  인용수  피인용수  발명자수  청구항수 작업구분코드         기업명 CRI등급
# ...

# %%
X1
# Out:
#             데이터수집일자                                                특허명  \
# 293      20220512.0                                휴대 단말기의 다이어리형 보호케이스
# 366      20220512.0  적외선 카메라와 객체 추적이 가능한 성범죄자 데이터베이스와 연동되는 지능형 비상벨 시스템
# 393      20220512.0           보안성을 강화한 안티 엘리어싱 기반의 폰트 표시방법 및 폰트 표시 시스템
# 395      20220512.0                     그리드 컴퓨팅 시스템 및 그리드 컴퓨팅 서비스 제공방법
# 494      20220512.0                                 노면표시용 문자 도색장치 및 방법
# ...             ...                                                ...
# 1026213  20220603.0                 지엔에스에스를 이용한 크레인 충돌방지 모니터링 시스템 및 방법
# 1026219  20220603.0                       모바일 단말을 이용한 gnss 측량 시스템 및 방법
# 1026291  20220603.0                                 강관파일을 이용한 흙막이 시공방법
# 1026502  20220603.0                                           지능형 트레일러
# 1027058  20220603.0                        인공지능 기반 악성 도메인 분류 방법 및 프로그램
#
#                 CPC번호  인용수  피인용수  발명자수  청구항수 작업구분코드         기업명 CRI등급
# ...

# %% [markdown]
# X1 = X1.drop('데이터수집일자_ob', axis = 1)
# X1

# %%
X1 = X1.drop('데이터수집일자', axis = 1)
X1 = X1.drop(columns=['작업구분코드'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [47], in <cell line: 1>()
# ----> 1 X1 = X1.drop('데이터수집일자', axis = 1)
#       2 X1 = X1.drop(columns=['작업구분코드'])
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
# 파이프라인 구축하기
from sklearn.pipeline import make_pipeline

# 스케일링과 인코딩
from sklearn.preprocessing import RobustScaler

# 숫자는 숫자끼리, 문자는 문자끼리 처리될 수 있도록 파이프라인을 별도로 구성하기
from sklearn.compose import make_column_transformer

from sklearn.preprocessing import OrdinalEncoder

# 학습 알고리즘 호출하기
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier

# 숫자가 처리되는 프로세스 구축하기
numeric_pipe = make_pipeline(RobustScaler())
numeric_pipe

# 문자가 처리되는 프로세스 구축하기
category_pipe = make_pipeline(OrdinalEncoder())
category_pipe

# %%
# 숫자는 숫자끼리, 문자는 문자끼리 처리되도록 파이프 구성하기
numeric_list = X1.describe().columns.tolist()
category_list = X1.describe(include = 'object').columns.tolist()

preprocessing_pipe = make_column_transformer((numeric_pipe, numeric_list), (category_pipe, category_list))
preprocessing_pipe

# %% [markdown]
# X1['특허명'].value_counts()

# %%
enc2 = OrdinalEncoder()
enc2.fit_transform(X1[['특허명']])[:10]
# Out:
# array([[5394.],
#        [3724.],
#        [1916.],
#        [ 714.],
#        [ 913.],
#        [1147.],
#        [4927.],
#        [3876.],
#        [ 443.],
#        [1424.]])

# %%
X1.columns
# Out:
# Index(['특허명', 'CPC번호', '인용수', '피인용수', '발명자수', '청구항수', '기업명', 'CRI등급'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

Y = X1['CRI등급']
X = X1[['특허명', 'CPC번호', '인용수', '피인용수', '발명자수', '청구항수', '기업명', 'CRI등급']]
x_train, x_test, y_train, y_test = train_test_split(X, Y, stratify = Y, test_size = 0.25, random_state = 1234)

# %%
# 특성공학 학습
model_pipe = make_pipeline(preprocessing_pipe, GradientBoostingClassifier())
model_pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('robustscaler',
#                                                                    RobustScaler())]),
#                                                   ['인용수', '피인용수', '발명자수',
#                                                    '청구항수']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('ordinalencoder',
#                                                                    OrdinalEncoder())]),
#                                                   ['특허명', 'CPC번호', '기업명',
#                                                    'CRI등급'])])),
#                 ('gradientboostingclassifier', GradientBoostingClassifier())])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics   import classification_report     # 평가

# %%
from sklearn.metrics import confusion_matrix

# %%
y_train_pred = model_pipe.predict(x_train)

# %%
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#           A1       1.00      1.00      1.00        78
#           A2       1.00      1.00      1.00       213
#           A3       1.00      1.00      1.00       496
#           B1       1.00      1.00      1.00       703
#           B2       1.00      1.00      1.00       796
#           B3       1.00      1.00      1.00       658
#           C1       1.00      1.00      1.00      1012
#           C2       1.00      1.00      1.00      3988
#           C3       1.00      1.00      1.00      1958
#            D       1.00      1.00      1.00       311
#           NG       1.00      1.00      1.00         8
#
#     accuracy                           1.00     10221
#    macro avg       1.00      1.00      1.00     10221
# weighted avg       1.00      1.00      1.00     10221

# %%
y_test_pred = model_pipe.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 y_test_pred = model_pipe.predict(x_test)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\pipeline.py:457, in Pipeline.predict(self, X, **predict_params)
#     455 Xt = X
#     456 for _, name, transform in self._iter(with_final=False):
# --> 457     Xt = transform.transform(Xt)
#     458 return self.steps[-1][1].predict(Xt, **predict_params)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\sklearn\compose\_column_transformer.py:763, in ColumnTransformer.transform(self, X)
#     758 else:
#     759     # ndarray was used for fitting or transforming, thus we only
#     760     # check that n_features_in_ is consistent
#     761     self._check_n_features(X, reset=False)
# --> 763 Xs = self._fit_transform(
#     764     X,
#     765     None,
# ...

# %%
print(classification_report(Y_test,Y_test_pred))

# %%
y_train_pred
# Out:
# array(['C2', 'B3', 'C2', ..., 'C3', 'C3', 'C2'], dtype=object)

# %%
print(precision_score(y_true, y_pred, average=None))  
print('precision (micro): %.4f' % precision_score(y_true, y_pred, average='micro'))   
print('precision (macro): %.4f' % precision_score(y_true, y_pred, average='macro'))    
print('precision (weighted): %.4f' % precision_score(y_true, y_pred, average='weighted'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 print(precision_score(y_true, y_pred, average=None))
#       2 print('precision (micro): %.4f' % precision_score(y_true, y_pred, average='micro'))
#       3 print('precision (macro): %.4f' % precision_score(y_true, y_pred, average='macro'))
#
# NameError: name 'y_true' is not defined
