# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import scipy.stats as stats

mpl.rc('font', family='Malgun Gothic')

# %%
# %matplotlib inline

# %%
pd.options.display.max_columns = 100

# %%
master_member = pd.read_csv('/content/drive/MyDrive/data_station/project/Data02_포장회사데이터/master_member.csv')

master_product = pd.read_csv('/content/drive/MyDrive/data_station/project/Data02_포장회사데이터/master_product.csv')

log_order = pd.read_csv('/content/drive/MyDrive/data_station/project/Data02_포장회사데이터/log_order.csv')

# %%
master_member.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '주소(동/읍/면)', '최종접속일', '최종주문일', '유입경로',
#        '유입기기', '회원 가입일', '사업자구분', '회원구분'],
#       dtype='object')

# %%
master_product.columns
# Out:
# Index(['#', '공급사', '과세/면세', '담기', '매입가', '상품명(기본)', '상품코드', '재입고알림', '제조사',
#        '카테고리', '판매가', '품절여부', '후기'],
#       dtype='object')

# %%
log_order.columns
# Out:
# Index(['결제수단', '공급원가', '교환구분', '네이버 포인트', '배송번호', '배송비 정보', '배송시작일', '배송완료일',
#        '사용한 적립금액', '상품구매금액', '상품명', '상품번호', '상품별 추가할인금액', '수량', '수령인 주소',
#        '주문 시 회원등급', '주문경로', '주문번호', '주문일시', '주문자ID', '카드사', '쿠폰 할인금액', '판매가',
#        '품목번호'],
#       dtype='object')

# %%
log_order.rename(columns = {'주문자ID':'ID'},inplace=True)
log_order
# Out:
#         결제수단     공급원가  교환구분  네이버 포인트                   배송번호 배송비 정보  \
# 0      무통장입금  44550.0  교환안함        0  D-20181227-0000648-00     무료
# 1      무통장입금  44000.0  교환안함        0  D-20181229-0000119-00     무료
# 2      무통장입금   6820.0  교환안함        0  D-20181230-0000100-00     무료
# 3      무통장입금  49500.0  교환안함        0  D-20181231-0000087-00     무료
# 4      무통장입금  61600.0  교환안함        0  D-20181231-0000108-00     무료
# ...      ...      ...   ...      ...                    ...    ...
# 46744     카드  36300.0  교환안함        0  D-20171229-0000036-00     무료
# 46745     카드  36300.0  교환안함        0  D-20171229-0000043-00     무료
# 46746     카드  22280.0  교환안함      300  D-20171230-0000022-01     무료
# 46747     카드  55000.0  교환안함      320  D-20171231-0000017-01     무료
# 46748     카드  52800.0  교환안함        0  D-20171231-0000026-00     무료
#
#                      배송시작일               배송완료일  사용한 적립금액  상품구매금액  \
# 0       2019-01-07 오전 8:56  2019-01-11 오전 5:32         0   71450
# 1       2019-01-03 오전 9:30  2019-01-07 오전 5:32         0  141240
# 2       2019-01-03 오전 9:30  2019-01-07 오전 5:32         0   13910
# 3       2019-01-03 오전 9:30  2019-01-07 오전 5:32         0   81600
# 4       2019-01-07 오전 8:56  2019-01-11 오전 5:32         0   94710
# ...                    ...                 ...       ...     ...
# 46744   2017-12-29 오후 4:32  2018-01-02 오전 5:31         0   52800
# 46745   2018-01-03 오전 9:45  2018-01-07 오전 5:38         0  112200
# 46746   2018-01-02 오후 7:06  2018-01-11 오전 2:46         0   36000
# 46747   2018-01-03 오후 2:00  2018-01-06 오후 6:06         0   73460
# 46748  2018-01-03 오후 12:43  2018-01-07 오전 5:38         0   81620
#
#                                                   상품명    상품번호  상품별 추가할인금액  수량  \
# 0                          195파이 탕용기 소 300개 1set(2박스)  1077.0       13600   1
# 1      95파이 다용도컵 세트 4호 소 200ml 백색 PS 1,000개 1set(2박스)    42.0       19800   2
# 2                                  비닐봉투 배달중 중 백색 200개  1271.0        2900   1
# 3                       195파이 미니탕용기 투톤 300개 1set(2박스)  1085.0       12630   1
# 4                          250파이 원형 접시 미니 블랙 400개 1박스  1106.0       18000   1
# ...                                               ...     ...         ...  ..
# 46744                          PP 4칸 도시락용기 A 200개 1박스   445.0        6340   1
# 46745                         PP 6칸 도시락용기 02 200개 1박스   172.0       13460   2
# 46746                          170mm 수저 투명 1,500개 1박스   140.0        3600   1
# 46747     170파이 원형 샐러드 3칸 150ml x 3 검정 400개 1set(2박스)   184.0        5140   1
# 46748         125파이 원형용기 중 350ml 백색 PP 600개 1set(2박스)   479.0       12240   1
#
#                              수령인 주소 주문 시 회원등급    주문경로              주문번호  \
# 0          경상남도 거제시 능포로 168-1 (능포동)   전화주문 고객   PC쇼핑몰  20181227-0000648
# 1        서울특별시 동대문구 한천로36길 16 (장안동)        일반    모바일웹  20181229-0000119
# 2             세종특별자치시 호려울로 29 (보람동)       NaN    모바일웹  20181230-0000100
# 3         부산광역시 부산진구 가야대로 482 (개금동)        일반    모바일웹  20181231-0000087
# 4      부산광역시 해운대구 선수촌로 104-21 (반여동)       사업자    모바일웹  20181231-0000108
# ...                             ...       ...     ...               ...
# 46744    서울특별시 서초구 강남대로97길 23 (잠원동)        일반    모바일웹  20171229-0000036
# 46745        경기도 의정부시 용민로 483 (민락동)       사업자    모바일웹  20171229-0000043
# 46746                 대전광역시 서구 관저2동       NaN  네이버 페이  20171230-0000022
# 46747         광주광역시 서구 화운로 152 (화정동       NaN  네이버 페이  20171231-0000017
# 46748   충청남도 천안시 서북구 성환읍 성환리 449-43        일반    모바일웹  20171231-0000026
#
#                       주문일시          ID      카드사  쿠폰 할인금액    판매가   품목번호
# 0       2018-12-27 오후 2:54       pp683      NaN        0  71450  42602
# 1       2018-12-29 오후 1:22     asd0908      NaN        0  70620  42930
# 2       2018-12-30 오후 3:15         NaN      NaN        0  13910  42998
# 3      2018-12-31 오전 10:30  23533593@n      NaN        0  81600  43063
# 4      2018-12-31 오전 10:43   romandoll      NaN        0  94710  43066
# ...                    ...         ...      ...      ...    ...    ...
# 46744   2017-12-29 오후 1:39  73987748@n       국민        0  52800   3170
# 46745   2017-12-29 오후 5:16   chuheesuk       비씨        0  56100   3172
# 46746   2017-12-30 오후 6:56         NaN       기타        0  36000   3177
# 46747  2017-12-31 오전 10:00         NaN       기타        0  73460   3178
# 46748   2017-12-31 오후 6:15    rmxehfdl  NH (농협)        0  81620   3179
#
# [46749 rows x 24 columns]

# %%
df = pd.merge(master_member,log_order, how='inner', on = 'ID')

# %%
df.isnull().sum()
# Out:
# ID                0
# 나이                0
# 사용가능 적립금          0
# 성별                0
# 주소(동/읍/면)       279
# 최종접속일             0
# 최종주문일             0
# 유입경로              0
# 유입기기              0
# 회원 가입일            0
# 사업자구분             0
# 회원구분              0
# 결제수단              0
# 공급원가             46
# 교환구분              0
# 네이버 포인트           0
# 배송번호              0
# 배송비 정보            0
# 배송시작일             0
# 배송완료일             0
# 사용한 적립금액          0
# 상품구매금액            0
# 상품명              46
# 상품번호             46
# 상품별 추가할인금액        0
# 수량                0
# 수령인 주소            0
# 주문 시 회원등급         0
# 주문경로              0
# 주문번호              0
# 주문일시              0
# 카드사           29046
# 쿠폰 할인금액           0
# 판매가               0
# 품목번호              0
# dtype: int64

# %%
def func1(row):
        if '무통장' in row:
                return '무통장입금'
        elif '카드' in row:
                return '카드'
        elif '실시간계좌이체' in row:
                return '실시간계좌이체'
        elif '휴대폰' in row:
                return '휴대폰'
        elif '가상계좌' in row:
                return '가상계좌'
        elif '카카오머니' in row:
                return '카카오머니'
        else:
                return '기타'



df['결제수단_cut'] = df['결제수단'].apply(func1)

# %%
df[df['결제수단_cut'] == '무통장입금']['카드사'].value_counts()
# Out:
# 삼성               28
# 롯데               23
# 신한(구.LG카드 포함)    14
# 현대               12
# NH (농협)          11
# 국민               10
# 비씨                8
# 외환                6
# 하나SK              3
# Name: 카드사, dtype: int64

# %%
df[df['카드사'].isna()]['결제수단_cut'].value_counts()
# Out:
# 무통장입금      28245
# 휴대폰          448
# 가상계좌         160
# 실시간계좌이체      120
# 기타            50
# 카카오머니         23
# Name: 결제수단_cut, dtype: int64

# %%
df['카드사'] = df['카드사'].fillna('카드아님')

# %%
df[df['주소(동/읍/면)'].isna()]['주소(동/읍/면)']
# Out:
# 770      NaN
# 20291    NaN
# 20292    NaN
# 20313    NaN
# 20314    NaN
#         ...
# 43511    NaN
# 43518    NaN
# 43519    NaN
# 43520    NaN
# 43521    NaN
# Name: 주소(동/읍/면), Length: 279, dtype: object

# %%
df['주소(동/읍/면)'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 43520     True
# 43521     True
# 43522    False
# 43523    False
# 43524    False
# Name: 주소(동/읍/면), Length: 43525, dtype: bool

# %%
def func2(row):
        if row == np.NaN:
            row = df['수령인 주소']

# %%
df['주소'] = df['주소(동/읍/면)'].fillna(0)
df['주소']

for i in df['주소']:
    if i == 0 :
         df['주소'] = df['수령인 주소']
    else:
        continue

# %%
df = df.drop('주소(동/읍/면)', axis =1)

# %%
df = df.dropna()

# %%
df['주소']
# Out:
# 0        전라북도 전주시 덕진구 동부대로 879 (호성동1가)
# 1           전라북도 전주시 완산구 효자동3가 1676-13
# 2           전라북도 전주시 완산구 효자동3가 1676-13
# 3           전라북도 전주시 완산구 효자동3가 1676-13
# 4             경기도 부천시 원미구 상일로 126 (상동)
#                      ...
# 43520        충청남도 공주시 한적2길 64-13 (금흥동)
# 43521            대전광역시 서구 도솔로 41 (도마동)
# 43522       경기도 의정부시 동일로454번길 40 (신곡동)
# 43523      경상남도 창원시 의창구 북면 무동로267번길 10
# 43524      경상남도 창원시 의창구 북면 무동로267번길 10
# Name: 주소, Length: 43479, dtype: object

# %%
# def func3(row):
#         row = row.split('(')[0]
#         row = row.split(' ')[0]
#         return row
    
# df['주소'].apply(func3).value_counts()

# %%
def func3(row):
        row = row.split(' ')[0]
        return row
    
df['시도'] = df['수령인 주소'].apply(func3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '최종접속일', '최종주문일', '유입경로', '유입기기',
#        '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트', '배송번호',
#        '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가', '품목번호', '결제수단_cut', '주소', '시도'],
#       dtype='object')

# %%
def func5(row):
        row = row.split(' ')[0]
        return row

# %%
df['주문일시_dt'] = pd.to_datetime(df['주문일시'].apply(func5))
df['주문일시_dt']

df['주문일시_년'] = df['주문일시_dt'].dt.year
df['주문일시_월'] = df['주문일시_dt'].dt.month
df['주문일시_일'] = df['주문일시_dt'].dt.day
df['주문일시_분기'] = df['주문일시_dt'].dt.quarter

# %%
df['주문일시'].isnull().sum()
# Out:
# 0

# %%
df.pivot_table(index='주문일시', values='판매가', aggfunc='sum')
# Out:
#                         판매가
# 주문일시
# 2017-01-01 오후 3:38    66500
# 2017-01-15 오전 1:24    17000
# 2017-01-18 오후 4:41    73700
# 2017-01-23 오전 12:35   17000
# 2017-02-02 오후 1:39    72000
# ...                     ...
# 2019-05-31 오후 6:32   138670
# 2019-06-02 오후 7:34   222370
# 2019-06-04 오후 12:29   61900
# 2019-06-19 오전 11:14   52400
# 2019-06-19 오전 11:18   60900
#
# [20433 rows x 1 columns]

# %%
def func(row):
        if row<30:
                return '20대'
        elif 30<=row<40:
                return '30대'
        elif 40<=row<50:
                return '40대'
        elif 50<=row<60:
                return '50대'
        elif 60<=row<70:
                return '60대'
        elif 70<=row<80:
                return '70대'
        elif 80<=row<90:
                return '80대'
        elif 90<=row:
                return '90대'

df['연령대'] = df['나이'].apply(func)

# %%
df_y_sale = df.pivot_table(index='시도', values='판매가',columns='주문일시_년', aggfunc='sum')
df_y_sale
# (df_y_sale[2018] - df_y_sale[2017]) /df_y_sale[2017]
# (df_y_sale[2019] - df_y_sale[2018]) /df_y_sale[2018]
# Out:
# 주문일시_년       2017       2018       2019
# 시도
# 강원도       1237440   64073320   48124410
# 경기도      10289830  216190760  211017430
# 경상남도      3805260  142639350  120071280
# 경상북도      2175150   86265570   76304750
# 광주광역시      509110   45681510   28329390
# 대구광역시     4219130   71317300   49895880
# 대전광역시     7845150   54022240   35563450
# 부산광역시     7741540  150103210  130895770
# 서울특별시    12528520  134593100  150621970
# 세종특별자치시     96850    9152780    9098750
# 울산광역시     2040780   47622120   31570080
# 인천광역시     3851950   60903570   34654150
# 전라남도      2519300   45831230   35586550
# 전라북도      1159450   59113790   45835920
# 제주특별자치도    117240   19088630   10545030
# 충청남도      1556280   60756820   45746980
# 충청북도      2029530   55870840   45572160

# %%
df_y_sale = df_y_sale.drop(columns=2017)
df_y_sale['증감율'] = (df_y_sale[2019] - df_y_sale[2018]) /df_y_sale[2018]
df_y_sale.to_excel('시도별판매증감율.xlsx')

# %%
df.pivot_table(index='연령대', values='판매가',columns='주문일시_년', aggfunc='sum')
# Out:
# 주문일시_년        2017         2018         2019
# 연령대
# 20대      5221680.0  210459460.0  216739590.0
# 30대     16220630.0  295950390.0  229512900.0
# 40대     30985480.0  697547860.0  620135650.0
# 50대      8764410.0   76008660.0   26329350.0
# 60대      2171310.0   17983670.0    7653450.0
# 70대       359000.0   24214990.0    7765940.0
# 80대            NaN     736360.0    1060830.0
# 90대            NaN     324750.0     236240.0

# %%
df.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '최종접속일', '최종주문일', '유입경로', '유입기기',
#        '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트', '배송번호',
#        '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가', '품목번호', '결제수단_cut', '주소', '시도', '주문일시_dt',
#        '주문일시_년', '주문일시_월', '주문일시_일', '주문일시_분기', '연령대'],
#       dtype='object')

# %%
df.pivot_table(index='유입기기', values='판매가',columns='주문일시_년', aggfunc='sum')
# Out:
# 주문일시_년      2017       2018       2019
# 유입기기
# PC      38379770  869076830  675494440
# 모바일     25342740  454149310  433939510

# %%
df_20 = df.loc[df['연령대']=='20대']
df_30 = df.loc[df['연령대']=='30대']
# df_20 = df.loc[df['연령대'].isin(['20대','30대'])]

# %%
df_20_c = df_20.pivot_table(index='유입기기', values='판매가',columns='주문일시_년', aggfunc='sum')
df_20_c2 = df_20_c.reset_index()
df_20_c2.to_excel('20,30대유입기기별사용.xlsx')
df_20_c2
# Out:
# 주문일시_년 유입기기     2017       2018       2019
# 0        PC  3649830  150689890  143681710
# 1       모바일  1571850   59769570   73057880

# %%
df_30_c = df_30.pivot_table(index='유입기기', values='판매가',columns='주문일시_년', aggfunc='sum')
df_30_c2 = df_30_c.reset_index()
df_30_c2.to_excel('30대유입기기별사용.xlsx')
df_30_c2
# Out:
# 주문일시_년 유입기기      2017       2018       2019
# 0        PC  11245330  227757720  166333200
# 1       모바일   4975300   68192670   63179700

# %%
df_20.pivot_table(index='유입기기', values='수량',columns='주문일시_년', aggfunc='sum')
# Out:
# 주문일시_년  2017  2018  2019
# 유입기기
# PC        72  3533  2604
# 모바일       47  1346  1442

# %%
df_30.pivot_table(index='유입기기', values='수량',columns='주문일시_년', aggfunc='sum')
# Out:
# 주문일시_년  2017  2018  2019
# 유입기기
# PC       248  4973  3117
# 모바일      129  1576  1089

# %%
1576+1346
# Out:
# 2922

# %%
p1 = df_20_c2[df_20_c2['유입기기']=='모바일']

sns.barplot(data=p1)
plt.title('년도별 20대 모바일 주문')
# stats.normaltest(df_20_c2[df_20_c2['유입기기']=='모바일'])
# Out:
# Text(0.5, 1.0, '년도별 20대 모바일 주문')
# WARNING:matplotlib.font_manager:findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47784 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48148 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# WARNING:matplotlib.font_manager:findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47784 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48148 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# '연령대'와 '유입기기'의 연관성이 있는지 가설검정을 수행

df1_table = pd.crosstab(df[df['연령대'].isin(['20대','30대'])]['연령대'], df[df['연령대'].isin(['20대','30대'])]['유입기기'])
stats.chi2_contingency(df1_table)
# 통계량 / P.value / 자유도 / 기댓값
# P.value < 0.05 대립가설 참 / 고객의 '연령대'와 '유입기기' 간의 연관성이 있다.
# Out:
# (39.96297445207209,
#  2.58822665372825e-10,
#  1,
#  array([[5565.36424225, 2138.63575775],
#         [6899.63575775, 2651.36424225]]))

# %%
df.pivot_table(index='유입기기', values='판매가', aggfunc='sum')
# Out:
#              판매가
# 유입기기
# PC    1582951040
# 모바일    913431560

# %%
df_age = df.pivot_table(index='유입기기', values='판매가',columns='연령대', aggfunc='sum')
df_age['총합'] = df.pivot_table(index='유입기기', values='판매가', aggfunc='sum')
df_age
age_list=['20대','30대','40대','50대','60대','70대','80대','90대']

# %%
for i in age_list :
    df_age[i] = df_age[i]/df_age['총합']*100

# %%
df_age
# Out:
# 연령대         20대        30대        40대       50대       60대       70대       80대  \
# 유입기기
# PC    18.826952  25.606367  47.555719  4.791244  1.320070  1.793105  0.097395
# 모바일   14.713669  14.926972  65.235894  3.860101  0.756747  0.433087  0.027968
#
# 연령대        90대          총합
# 유입기기
# PC    0.009148  1582951040
# 모바일   0.045562   913431560

# %%
#     - '판매가'의 정규성을 확인
#     - '20대'과 '30대' 집단의 '판매가'의 평균의 차이가 있는지 가설검정을 수행하십시오.
cond1 = df['연령대'] == '20대'
cond2 = df['연령대'] == '30대'

stats.normaltest(df[df['연령대'].isin(['20대','30대'])]['판매가'])
# p.value < 0.05 / 대립가설 참 / 분포가 정규분포를 따르지 않는다.
# Out:
# NormaltestResult(statistic=8200.90501191791, pvalue=0.0)

# %%
stats.ranksums(df.loc[df['연령대'].isin(['20대','30대'])]['판매가'], df.loc[~(df['연령대'].isin(['20대','30대']))]['판매가'])
# P.value < 0.05 / 대립가설 참 / 두 집단의 판매가 값의 평균의 차이가 있다.
# Out:
# RanksumsResult(statistic=-4.1193323288158155, pvalue=3.799717996933387e-05)

# %%
df.head(2)
# Out:
#         ID  나이  사용가능 적립금  성별                최종접속일                최종주문일   유입경로  \
# 0  cgh1385  53         0  남자  2017-01-02 오후 12:32   2017-01-01 오후 3:38  블로그광고
# 1   pjkl77  28         0  남자  2017-02-26 오후 10:52  2017-02-26 오후 10:55  이메일광고
#
#   유입기기      회원 가입일 사업자구분 회원구분   결제수단     공급원가  교환구분  네이버 포인트  \
# 0  모바일  2017-01-01    개인   일반  무통장입금  51700.0  교환안함        0
# 1   PC  2017-01-14   사업자  사업자  쿠폰,카드   6200.0  교환안함        0
#
#                     배송번호 배송비 정보               배송시작일               배송완료일  \
# 0  D-20170101-0000015-00     선불  2017-01-17 오전 8:26  2017-01-17 오전 8:26
# 1  D-20170115-0000013-00     선불  2017-01-19 오전 8:56  2017-01-19 오후 7:51
#
#    사용한 적립금액  상품구매금액                                              상품명  상품번호  \
# 0         0   66500  105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)  45.0
# 1         0   17000           소량 105파이 다용도컵 세트 5호 대 370ml 투명 PS 100개  67.0
#
#    상품별 추가할인금액  수량                         수령인 주소 주문 시 회원등급   주문경로  \
# 0           0   1  전라북도 전주시 덕진구 동부대로 879 (호성동1가)        일반   모바일웹
# 1           0   1     전라북도 전주시 완산구 효자동3가 1676-13        일반  PC쇼핑몰
#
#                주문번호                주문일시      카드사  쿠폰 할인금액    판매가  품목번호  \
# 0  20170101-0000015  2017-01-01 오후 3:38     카드아님        0  66500     4
# 1  20170115-0000013  2017-01-15 오전 1:24  NH (농협)     5000  17000     9
#
#   결제수단_cut                             주소    시도    주문일시_dt  주문일시_년  주문일시_월  \
# 0    무통장입금  전라북도 전주시 덕진구 동부대로 879 (호성동1가)  전라북도 2017-01-01    2017       1
# 1       카드     전라북도 전주시 완산구 효자동3가 1676-13  전라북도 2017-01-15    2017       1
#
#    주문일시_일  주문일시_분기  연령대
# 0       1        1  50대
# 1      15        1  20대

# %% [markdown]
# # 전체 df

# %%
# 판매가, 성별, 유입경로, 유입기기, 사업자구분, 회원구분
df.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '최종접속일', '최종주문일', '유입경로', '유입기기',
#        '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트', '배송번호',
#        '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가', '품목번호', '결제수단_cut', '주소', '시도', '주문일시_dt',
#        '주문일시_년', '주문일시_월', '주문일시_일', '주문일시_분기', '연령대'],
#       dtype='object')

# %%
df['주문일시_월'].value_counts()
# Out:
# 5     5474
# 4     4943
# 3     4183
# 12    4136
# 11    3998
# 1     3888
# 10    3646
# 2     3308
# 8     3029
# 7     2608
# 9     2333
# 6     1933
# Name: 주문일시_월, dtype: int64

# %%
stats.normaltest(df['판매가'])
# p.value < 0.05 / 대립가설 참 / 분포가 정규분포를 따르지 않는다.
# Out:
# NormaltestResult(statistic=21870.201788507504, pvalue=0.0)

# %%
stats.normaltest(df['나이'])
# p.value < 0.05 / 대립가설 참 / 분포가 정규분포를 따르지 않는다.
# Out:
# NormaltestResult(statistic=5793.735625645794, pvalue=0.0)

# %%
# '연령대'와 '유입경로'의 연관성이 있는지 가설검정을 수행

df_table = pd.crosstab(df['연령대'], df['유입경로'])
stats.chi2_contingency(df_table)
# 통계량 / P.value / 자유도 / 기댓값
# P.value < 0.05 대립가설 참 / 연령대와 유입경로 간의 연관성이 있다.
# Out:
# (35766.59545725008,
#  0.0,
#  77,
#  array([[9.41227903e+02, 4.11787208e+02, 6.52587042e+02, 9.46189195e+01,
#          7.76973711e+02, 9.51504864e+02, 4.53780998e+02, 8.12588698e+02,
#          7.53053198e+02, 7.90440075e+02, 6.31501552e+02, 4.33935831e+02],
#         [1.16688314e+03, 5.10511373e+02, 8.09041905e+02, 1.17303388e+02,
#          9.63249730e+02, 1.17962396e+03, 5.62572989e+02, 1.00740325e+03,
#          9.33594379e+02, 9.79944594e+02, 7.82901263e+02, 5.37970032e+02],
#         [2.87169806e+03, 1.25636790e+03, 1.99105120e+03, 2.88683502e+02,
#          2.37055648e+03, 2.90305320e+03, 1.38449148e+03, 2.47921824e+03,
#          2.29757469e+03, 2.41164252e+03, 1.92671911e+03, 1.32394363e+03],
#         [2.17836105e+02, 9.53032958e+01, 1.51033579e+02, 2.18984337e+01,
#          1.79821408e+02, 2.20214586e+02, 1.05022264e+02, 1.88064077e+02,
#          1.74285287e+02, 1.82938039e+02, 1.46153591e+02, 1.00429334e+02],
#         [5.30234826e+01, 2.31977736e+01, 3.67630810e+01, 5.33029738e+00,
#          4.37703259e+01, 5.36024288e+01, 2.55634674e+01, 4.57766738e+01,
#          4.24227788e+01, 4.45289450e+01, 3.55752432e+01, 2.44455024e+01],
#         [5.69330481e+01, 2.49082086e+01, 3.94737229e+01, 5.72331470e+00,
#          4.69976310e+01, 5.75546816e+01, 2.74483314e+01, 4.91519124e+01,
#          4.55507256e+01, 4.78121852e+01, 3.81983026e+01, 2.62479358e+01],
#         [3.17652200e+00, 1.38972837e+00, 2.20239656e+00, 3.19326571e-01,
#          2.62218542e+00, 3.21120541e+00, 1.53145197e+00, 2.74238138e+00,
#          2.54145680e+00, 2.66763265e+00, 2.13123577e+00, 1.46447710e+00],
#         [1.22173923e+00, 5.34510913e-01, 8.47075600e-01, 1.22817912e-01,
#          1.00853285e+00, 1.23507900e+00, 5.89019987e-01, 1.05476207e+00,
#          9.77483383e-01, 1.02601256e+00, 8.19706065e-01, 5.63260425e-01]]))

# %%
# '연령대'와 '유입기기'의 연관성이 있는지 가설검정을 수행

df_table = pd.crosstab(df['연령대'], df['유입기기'])
stats.chi2_contingency(df_table)
# 통계량 / P.value / 자유도 / 기댓값
# P.value < 0.05 대립가설 참 / 연령대와 유입기기 간의 연관성이 있다.
# Out:
# (1312.7265287342816,
#  2.9376186371206453e-279,
#  7,
#  array([[4.91947506e+03, 2.78452494e+03],
#         [6.09889749e+03, 3.45210251e+03],
#         [1.50093797e+04, 8.49562030e+03],
#         [1.13855452e+03, 6.44445479e+02],
#         [2.77135537e+02, 1.56864463e+02],
#         [2.97569493e+02, 1.68430507e+02],
#         [1.66025898e+01, 9.39741024e+00],
#         [6.38561144e+00, 3.61438856e+00]]))

# %%
# '시도'와 '주문경로'의 연관성이 있는지 가설검정을 수행

df_table = pd.crosstab(df['시도'], df['주문경로'])
stats.chi2_contingency(df_table)
# 통계량 / P.value / 자유도 / 기댓값
# P.value < 0.05 대립가설 참 / 시도와 주문경로 간의 연관성이 있다.
# Out:
# (480.4620206292681,
#  4.40309599695775e-92,
#  16,
#  array([[1204.294303  ,  867.705697  ],
#         [4399.8590124 , 3170.1409876 ],
#         [2696.29405   , 1942.70595   ],
#         [1665.78545965, 1200.21454035],
#         [ 760.82106304,  548.17893696],
#         [1290.89654776,  930.10345224],
#         [ 997.37887256,  718.62112744],
#         [2928.78329768, 2110.21670232],
#         [2916.57761218, 2101.42238782],
#         [ 191.22240622,  137.77759378],
#         [ 850.91064652,  613.08935348],
#         [1038.0644909 ,  747.9355091 ],
#         [ 811.38747441,  584.61252559],
#         [ 990.40419513,  713.59580487],
#         [ 288.28666713,  207.71333287],
#         [1153.72789163,  831.27210837],
#         [1086.3060098 ,  782.6939902 ]]))

# %%
# '시도'와 '유입기기'의 연관성이 있는지 가설검정을 수행

df_table = pd.crosstab(df['시도'], df['유입기기'])
stats.chi2_contingency(df_table)
# 통계량 / P.value / 자유도 / 기댓값
# P.value < 0.05 대립가설 참 / 시도와 유입기기 간의 연관성이 있다.
# Out:
# (676.9787383216681,
#  1.021803581629471e-133,
#  16,
#  array([[1323.09869132,  748.90130868],
#         [4833.90786357, 2736.09213643],
#         [2962.28514915, 1676.71485085],
#         [1830.11624002, 1035.88375998],
#         [ 835.8765381 ,  473.1234619 ],
#         [1418.24430185,  802.75569815],
#         [1095.77092389,  620.22907611],
#         [3217.70960694, 1821.29039306],
#         [3204.2998229 , 1813.7001771 ],
#         [ 210.08661653,  118.91338347],
#         [ 934.85351549,  529.14648451],
#         [1140.47020401,  645.52979599],
#         [ 891.43135767,  504.56864233],
#         [1088.10819016,  615.89180984],
#         [ 316.72632765,  179.27367235],
#         [1267.54387175,  717.45612825],
#         [1193.470779  ,  675.529221  ]]))

# %%
# '연령대'와 '사업자구분'의 연관성이 있는지 가설검정을 수행

df_table = pd.crosstab(df['연령대'], df['사업자구분'])
stats.chi2_contingency(df_table)
# 통계량 / P.value / 자유도 / 기댓값
# P.value < 0.05 대립가설 참 / 연령대와 유입기기 간의 연관성이 있다.
# Out:
# (1027.7516669341908,
#  1.7356749453276813e-210,
#  14,
#  array([[3.99029600e+03, 3.71334962e+03, 3.54377976e-01],
#         [4.94695186e+03, 4.60360880e+03, 4.39338531e-01],
#         [1.21744428e+04, 1.13294760e+04, 1.08121162e+00],
#         [9.23506980e+02, 8.59411003e+02, 8.20166057e-02],
#         [2.24790819e+02, 2.09189218e+02, 1.99636606e-02],
#         [2.41365257e+02, 2.24613308e+02, 2.14356356e-02],
#         [1.34667311e+01, 1.25320730e+01, 1.19597967e-03],
#         [5.17951195e+00, 4.82002806e+00, 4.59992180e-04]]))

# %%
df['주문일시_월'].dtype
# Out:
# dtype('int64')

# %%
# 1~5월까지만 추출
df2 = df.loc[df['주문일시_월'].isin([1,2,3,4,5])]
df2['주문일시_월'].value_counts()
# Out:
# 5    5474
# 4    4943
# 3    4183
# 1    3888
# 2    3308
# Name: 주문일시_월, dtype: int64

# %%
stats.normaltest(df2['판매가'])
# p.value < 0.05 / 대립가설 참 / 분포가 정규분포를 따르지 않는다.
# Out:
# NormaltestResult(statistic=18333.126653547115, pvalue=0.0)

# %%
stats.normaltest(df2['나이'])
# p.value < 0.05 / 대립가설 참 / 분포가 정규분포를 따르지 않는다.
# Out:
# NormaltestResult(statistic=2632.3566380437233, pvalue=0.0)

# %%
cond0 = df2['연령대'].isin(['20대','30대'])

stats.ranksums(df2[cond0]['판매가'],df2[~cond0]['판매가'])
# P.value > 0.05 / 귀무가설 참 / 두 집단의 값의 평균의 차이가 없다.
# Out:
# RanksumsResult(statistic=-1.783703707544104, pvalue=0.07447182338374816)

# %% [markdown]
# ## 2017년도 별 매출

# %%
# 2017년도 매출로
df17 = df2[df2['주문일시_년']==2017]
df17
# Out:
#                ID  나이  사용가능 적립금  성별                최종접속일                최종주문일  \
# 0         cgh1385  53         0  남자  2017-01-02 오후 12:32   2017-01-01 오후 3:38
# 1          pjkl77  28         0  남자  2017-02-26 오후 10:52  2017-02-26 오후 10:55
# 2          pjkl77  28         0  남자  2017-02-26 오후 10:52  2017-02-26 오후 10:55
# 3          pjkl77  28         0  남자  2017-02-26 오후 10:52  2017-02-26 오후 10:55
# 40        bear011  40     21908  남자   2018-12-19 오후 1:26   2018-12-19 오후 1:29
# ..            ...  ..       ...  ..                  ...                  ...
# 712      byulsina  47         0  여자   2017-05-30 오후 4:23   2017-05-30 오후 4:36
# 713      byulsina  47         0  여자   2017-05-30 오후 4:23   2017-05-30 오후 4:36
# 714  chlwotjr1019  34         0  남자   2017-05-30 오후 5:44   2017-05-30 오후 5:49
# 753    duruzoon70  40     10980  남자   2019-05-30 오후 2:31   2019-05-30 오후 2:32
# 754    duruzoon70  40     10980  남자   2019-05-30 오후 2:31   2019-05-30 오후 2:32
#
#         유입경로 유입기기      회원 가입일 사업자구분 회원구분      결제수단     공급원가  교환구분  네이버 포인트  \
# 0      블로그광고  모바일  2017-01-01    개인   일반     무통장입금  51700.0  교환안함        0
# 1      이메일광고   PC  2017-01-14   사업자  사업자     쿠폰,카드   6200.0  교환안함        0
# 2      이메일광고   PC  2017-01-14   사업자  사업자     쿠폰,카드   6200.0  교환안함        0
# 3      이메일광고   PC  2017-01-14   사업자  사업자  페이나우(카드)   6200.0  교환안함        0
# 40     SNS광고  모바일  2017-01-17   사업자  사업자     무통장입금  69300.0  교환안함        0
# ..       ...  ...         ...   ...  ...       ...      ...   ...      ...
# 712    SNS광고  모바일  2017-05-30    개인   일반    쿠폰,휴대폰   6750.0  교환안함        0
# 713    SNS광고  모바일  2017-05-30    개인   일반    쿠폰,휴대폰   6750.0  교환안함        0
# 714    이메일광고   PC  2017-05-30   사업자  사업자     무통장입금  42900.0  교환안함        0
# 753  인터넷기사광고   PC  2017-05-30   사업자  사업자        카드  42240.0  교환안함        0
# 754  인터넷기사광고   PC  2017-05-30   사업자  사업자        카드  33000.0  교환안함        0
#
#                       배송번호 배송비 정보                배송시작일               배송완료일  \
# 0    D-20170101-0000015-00     선불   2017-01-17 오전 8:26  2017-01-17 오전 8:26
# 1    D-20170115-0000013-00     선불   2017-01-19 오전 8:56  2017-01-19 오후 7:51
# 2    D-20170123-0000021-00     선불   2017-01-23 오후 3:26  2017-01-24 오후 6:00
# 3    D-20170226-0000015-00     선불   2017-02-27 오후 3:26  2017-03-01 오전 9:45
# 40   D-20170327-0000028-00     착불   2017-03-27 오후 5:06  2017-03-27 오후 5:06
# ..                     ...    ...                  ...                 ...
# 712  D-20170530-0000111-00     무료  2017-06-02 오전 11:54  2017-06-08 오전 5:40
# 713  D-20170530-0000111-01     무료  2017-06-02 오전 11:54  2017-06-08 오전 5:40
# 714  D-20170530-0000121-00     무료   2017-05-31 오후 4:44  2017-06-06 오전 5:41
# 753  D-20170530-0000035-00     무료   2017-05-31 오후 4:44  2017-06-06 오전 5:41
# 754  D-20170530-0000035-01     무료  2017-06-02 오전 11:54  2017-06-08 오전 5:40
#
#      사용한 적립금액  상품구매금액                                              상품명   상품번호  \
# 0           0   66500  105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)   45.0
# 1           0   17000           소량 105파이 다용도컵 세트 5호 대 370ml 투명 PS 100개   67.0
# 2           0   17000           소량 105파이 다용도컵 세트 5호 대 370ml 투명 PS 100개   67.0
# 3           0   17000           소량 105파이 다용도컵 세트 5호 대 370ml 투명 PS 100개   67.0
# 40          0   84600        300파이 원형 찜용기 왕대 투명 4,500ml 100개 1set(2박스)   86.0
# ..        ...     ...                                              ...    ...
# 712         0   13500                  170파이 샐러드 3칸 (150ml x 3)/검정/50개  185.0
# 713         0   13500                  170파이 샐러드 2칸 (250ml x 2)/검정/50개  181.0
# 714         0   53100    70파이 다용도컵 세트 1호 소 70ml 백색 PS 3,000개 1set(2박스)   38.0
# 753         0   57000    190 실링필름  Hold 190mm x 200 meter 투명 무지 4롤 1박스  252.0
# 754         0   47000     150 실링필름 Hold 150mm x 200 meter 투명 무지 4롤 1박스  248.0
#
#      상품별 추가할인금액  수량                         수령인 주소 주문 시 회원등급   주문경로  \
# 0             0   1  전라북도 전주시 덕진구 동부대로 879 (호성동1가)        일반   모바일웹
# 1             0   1     전라북도 전주시 완산구 효자동3가 1676-13        일반  PC쇼핑몰
# 2             0   1     전라북도 전주시 완산구 효자동3가 1676-13       사업자  PC쇼핑몰
# 3             0   1     전라북도 전주시 완산구 효자동3가 1676-13       사업자  PC쇼핑몰
# 40            0   1       경기도 부천시 원미구 상일로 126 (상동)       사업자  PC쇼핑몰
# ..          ...  ..                            ...       ...    ...
# 712           0   1       서울특별시 구로구 공원로8길 36 (구로동)        일반   모바일웹
# 713           0   1       서울특별시 구로구 공원로8길 36 (구로동)        일반   모바일웹
# 714        5310   1               충청북도 청주시 흥덕구 봉명동        일반  PC쇼핑몰
# 753           0   1            경상북도 칠곡군 석적읍 유학로 52        일반  PC쇼핑몰
# 754           0   1            경상북도 칠곡군 석적읍 유학로 52        일반  PC쇼핑몰
#
#                  주문번호                 주문일시      카드사  쿠폰 할인금액    판매가  품목번호  \
# 0    20170101-0000015   2017-01-01 오후 3:38     카드아님        0  66500     4
# 1    20170115-0000013   2017-01-15 오전 1:24  NH (농협)     5000  17000     9
# 2    20170123-0000021  2017-01-23 오전 12:35  NH (농협)     3000  17000    19
# 3    20170226-0000015  2017-02-26 오후 10:55  NH (농협)        0  17000    67
# 40   20170327-0000028   2017-03-27 오전 9:19     카드아님        0  84600   137
# ..                ...                  ...      ...      ...    ...   ...
# 712  20170530-0000111   2017-05-30 오후 4:36     카드아님     2000  13500   473
# 713  20170530-0000111   2017-05-30 오후 4:36     카드아님     2000  13500   474
# 714  20170530-0000121   2017-05-30 오후 5:49     카드아님        0  53100   475
# 753  20170530-0000035  2017-05-30 오전 11:01       현대        0  57000   464
# 754  20170530-0000035  2017-05-30 오전 11:01       현대        0  47000   465
#
#     결제수단_cut                             주소     시도    주문일시_dt  주문일시_년  주문일시_월  \
# 0      무통장입금  전라북도 전주시 덕진구 동부대로 879 (호성동1가)   전라북도 2017-01-01    2017       1
# 1         카드     전라북도 전주시 완산구 효자동3가 1676-13   전라북도 2017-01-15    2017       1
# 2         카드     전라북도 전주시 완산구 효자동3가 1676-13   전라북도 2017-01-23    2017       1
# 3         카드     전라북도 전주시 완산구 효자동3가 1676-13   전라북도 2017-02-26    2017       2
# 40     무통장입금       경기도 부천시 원미구 상일로 126 (상동)    경기도 2017-03-27    2017       3
# ..       ...                            ...    ...        ...     ...     ...
# 712      휴대폰       서울특별시 구로구 공원로8길 36 (구로동)  서울특별시 2017-05-30    2017       5
# 713      휴대폰       서울특별시 구로구 공원로8길 36 (구로동)  서울특별시 2017-05-30    2017       5
# 714    무통장입금               충청북도 청주시 흥덕구 봉명동   충청북도 2017-05-30    2017       5
# 753       카드            경상북도 칠곡군 석적읍 유학로 52   경상북도 2017-05-30    2017       5
# 754       카드            경상북도 칠곡군 석적읍 유학로 52   경상북도 2017-05-30    2017       5
#
#      주문일시_일  주문일시_분기  연령대
# 0         1        1  50대
# 1        15        1  20대
# 2        23        1  20대
# 3        26        1  20대
# 40       27        1  40대
# ..      ...      ...  ...
# 712      30        2  40대
# 713      30        2  40대
# 714      30        2  30대
# 753      30        2  40대
# 754      30        2  40대
#
# [141 rows x 43 columns]

# %%
df17_m = df17.pivot_table(index='주문일시_월', values='판매가', aggfunc='mean').reset_index()
df17_m
# Out:
#    주문일시_월           판매가
# 0       1  43550.000000
# 1       2  49455.333333
# 2       3  62494.000000
# 3       4  58986.428571
# 4       5  48758.750000

# %%
df17_m#[['주문일시_월']].value_counts())
df17[['주문일시_월', '판매가']]
# Out:
#      주문일시_월    판매가
# 0         1  66500
# 1         1  17000
# 2         1  17000
# 3         2  17000
# 40        3  84600
# ..      ...    ...
# 712       5  13500
# 713       5  13500
# 714       5  53100
# 753       5  57000
# 754       5  47000
#
# [141 rows x 2 columns]

# %%
sns.histplot(df17, x='판매가')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#     - '판매가'의 정규성을 확인

stats.normaltest(df17['판매가']) # pvalue=0.11491665049462017
# p.value > 0.05 / 귀무가설 참 / 분포가 정규분포를 따른다
# Out:
# NormaltestResult(statistic=4.327096383410628, pvalue=0.11491665049462017)

# %%
cond1 = df17['연령대'].isin(['20대','30대'])

# %%
stats.bartlett(df17[cond1]['판매가'], df17[~cond1]['판매가'])
# p.value > 0.05 / 귀무가설 참 / 등분산
# Out:
# BartlettResult(statistic=0.1621478960589292, pvalue=0.6871866511387326)

# %%
stats.ttest_ind(df17[cond1]['판매가'], df17[~cond1]['판매가'])
# p.value > 0.05 / 귀무가설 참 / 평균의 차이가 없다
# Out:
# Ttest_indResult(statistic=0.10711905244541083, pvalue=0.9148489860519837)

# %%
# '연령대'와 '유입경로'의 연관성이 있는지 가설검정을 수행

df17_table = pd.crosstab(df17['연령대'], df17['유입경로'])
stats.chi2_contingency(df17_table)
# 통계량 / P.value / 자유도 / 기댓값
# P.value < 0.05 대립가설 참 / 연령대와 유입경로 간의 연관성이 있다.
# Out:
# (152.67041537335655,
#  2.7096997515243808e-20,
#  25,
#  array([[ 1.83687943,  2.58156028,  0.44680851,  0.74468085,  0.89361702,
#           0.4964539 ],
#         [ 9.44680851, 13.27659574,  2.29787234,  3.82978723,  4.59574468,
#           2.55319149],
#         [22.30496454, 31.34751773,  5.42553191,  9.04255319, 10.85106383,
#           6.02836879],
#         [ 1.57446809,  2.21276596,  0.38297872,  0.63829787,  0.76595745,
#           0.42553191],
#         [ 1.57446809,  2.21276596,  0.38297872,  0.63829787,  0.76595745,
#           0.42553191],
#         [ 0.26241135,  0.36879433,  0.06382979,  0.10638298,  0.12765957,
#           0.07092199]]))

# %% [markdown]
# ## 2018년도 별 매출

# %%
# 2018년도 매출로
df18 = df2[df2['주문일시_년']==2018]
df18
# Out:
#                  ID  나이  사용가능 적립금  성별                최종접속일  \
# 4           bear011  40     21908  남자   2018-12-19 오후 1:26
# 5           bear011  40     21908  남자   2018-12-19 오후 1:26
# 45       91559380@n  47       700  남자   2018-05-09 오후 1:49
# 46       91559380@n  47       700  남자   2018-05-09 오후 1:49
# 47       91559380@n  47       700  남자   2018-05-09 오후 1:49
# ...             ...  ..       ...  ..                  ...
# 18754         pp422  31         0  남자   2018-12-10 오전 9:12
# 18757  romandoll123  48      2790  남자   2018-06-14 오전 8:19
# 18758  romandoll123  48      2790  남자   2018-06-14 오전 8:19
# 18761       yun5147  44      2050  남자  2018-06-05 오전 10:31
# 18762       yun5147  44      2050  남자  2018-06-05 오전 10:31
#
#                      최종주문일   유입경로 유입기기      회원 가입일 사업자구분     회원구분      결제수단  \
# 4       2018-12-19 오후 1:29  SNS광고  모바일  2017-01-17   사업자      사업자     무통장입금
# 5       2018-12-19 오후 1:29  SNS광고  모바일  2017-01-17   사업자      사업자     무통장입금
# 45      2018-05-09 오후 2:32  블로그광고   PC  2017-02-02    개인       일반        카드
# 46      2018-05-09 오후 2:32  블로그광고   PC  2017-02-02    개인       일반        카드
# 47      2018-05-09 오후 2:32  블로그광고   PC  2017-02-02    개인       일반  페이나우(카드)
# ...                    ...    ...  ...         ...   ...      ...       ...
# 18754   2018-12-10 오전 9:15  이메일광고   PC  2018-05-31    개인  전화주문 고객     무통장입금
# 18757   2018-06-14 오전 8:22  블로그광고   PC  2018-05-31    개인       일반     무통장입금
# 18758   2018-06-14 오전 8:22  블로그광고   PC  2018-05-31    개인       일반     무통장입금
# 18761  2018-06-05 오전 10:35  SNS광고  모바일  2018-05-31   사업자      사업자        카드
# 18762  2018-06-05 오전 10:35  SNS광고  모바일  2018-05-31   사업자      사업자        카드
#
#           공급원가  교환구분  네이버 포인트                   배송번호 배송비 정보  \
# 4      51040.0  교환안함        0  D-20180512-0000093-00     무료
# 5       1910.0  교환안함        0  D-20180512-0000093-00     무료
# 45     55000.0  교환안함        0  D-20180416-0000362-00     무료
# 46     19030.0  교환안함        0  D-20180416-0000362-00     무료
# 47     55000.0  교환안함        0  D-20180509-0000382-00     무료
# ...        ...   ...      ...                    ...    ...
# 18754   3000.0  교환안함        0  D-20180531-0000471-00     무료
# 18757  79200.0  교환안함        0  D-20180531-0000049-00     무료
# 18758   3000.0  교환안함        0  D-20180531-0000049-00     무료
# 18761  52800.0  교환안함        0  D-20180531-0000536-00     무료
# 18762  19030.0  교환안함        0  D-20180531-0000536-00     무료
#
#                      배송시작일               배송완료일  사용한 적립금액  상품구매금액  \
# 4      2018-05-18 오전 11:07  2018-05-22 오전 5:32         0   75390
# 5      2018-05-18 오전 11:07  2018-05-22 오전 5:32         0       0
# 45      2018-04-17 오후 6:14  2018-04-21 오전 5:32         0   77000
# 46      2018-04-17 오후 6:14  2018-04-21 오전 5:32         0       0
# 47      2018-05-11 오후 2:05  2018-05-15 오전 5:32         0   81500
# ...                    ...                 ...       ...     ...
# 18754   2018-06-01 오후 5:37  2018-06-05 오전 5:32         0       0
# 18757   2018-06-01 오후 3:12  2018-06-05 오전 5:32         0  109870
# 18758   2018-06-01 오후 3:12  2018-06-05 오전 5:32         0       0
# 18761   2018-06-01 오후 5:37  2018-06-05 오전 5:32         0   85400
# 18762   2018-06-01 오후 5:37  2018-06-05 오전 5:32         0       0
#
#                                                상품명    상품번호  상품별 추가할인금액  수량  \
# 4                      실링용기 2호 백색 1,150ml 800개 1박스   966.0       15000   1
# 5                                사은품) 위생 청 수세미(3개)  1136.0           0   1
# 45     170파이 원형 샐러드 3칸 150ml x 3 검정 400개 1set(2박스)   184.0        5300   1
# 46                                    사은품) 위생 랩 2호   353.0           0   1
# 47     170파이 원형 샐러드 3칸 150ml x 3 검정 400개 1set(2박스)   184.0       10000   1
# ...                                            ...     ...         ...  ..
# 18754                                      위생 랩 4호  1159.0           0   1
# 18757                       210파이 중화면용기 대 400개 1박스  1037.0       20000   1
# 18758                                      위생 랩 2호  1165.0           0   1
# 18761                      PP 7칸 도시락용기 L2 200개 1박스   450.0       15000   1
# 18762                                 사은품) 위생 랩 2호   353.0           0   1
#
#                                 수령인 주소 주문 시 회원등급   주문경로              주문번호  \
# 4             경기도 부천시 원미구 상일로 126 (상동)       사업자  PC쇼핑몰  20180512-0000093
# 5             경기도 부천시 원미구 상일로 126 (상동)       사업자  PC쇼핑몰  20180512-0000093
# 45              광주광역시 서구 화운로 152 (화정동)        일반  PC쇼핑몰  20180416-0000362
# 46              광주광역시 서구 화운로 152 (화정동)        일반  PC쇼핑몰  20180416-0000362
# 47              광주광역시 서구 화운로 152 (화정동)        일반  PC쇼핑몰  20180509-0000382
# ...                                ...       ...    ...               ...
# 18754  경기도 용인시 기흥구 용구대로2469번길 20 (보정동)        일반  PC쇼핑몰  20180531-0000471
# 18757            부산광역시 해운대구 반여동 1212-2        일반  PC쇼핑몰  20180531-0000049
# 18758            부산광역시 해운대구 반여동 1212-2        일반  PC쇼핑몰  20180531-0000049
# 18761        부산광역시 중구 광복로 96-1 (광복동1가)        일반   모바일웹  20180531-0000536
# 18762        부산광역시 중구 광복로 96-1 (광복동1가)        일반   모바일웹  20180531-0000536
#
#                       주문일시            카드사  쿠폰 할인금액     판매가   품목번호 결제수단_cut  \
# 4       2018-05-12 오후 2:10           카드아님        0   75390   9588    무통장입금
# 5       2018-05-12 오후 2:10           카드아님        0       0   9589    무통장입금
# 45      2018-04-16 오후 6:22             비씨        0   77000   7606       카드
# 46      2018-04-16 오후 6:22             비씨        0       0   7607       카드
# 47      2018-05-09 오후 2:32  신한(구.LG카드 포함)        0   81500   9320       카드
# ...                    ...            ...      ...     ...    ...      ...
# 18754   2018-05-31 오후 5:27           카드아님        0       0  11760    무통장입금
# 18757   2018-05-31 오전 1:59           카드아님        0  109870  11640    무통장입금
# 18758   2018-05-31 오전 1:59           카드아님        0       0  11641    무통장입금
# 18761  2018-05-31 오후 11:29             삼성        0   85400  11775       카드
# 18762  2018-05-31 오후 11:29             삼성        0       0  11776       카드
#
#                                     주소     시도    주문일시_dt  주문일시_년  주문일시_월  \
# 4             경기도 부천시 원미구 상일로 126 (상동)    경기도 2018-05-12    2018       5
# 5             경기도 부천시 원미구 상일로 126 (상동)    경기도 2018-05-12    2018       5
# 45              광주광역시 서구 화운로 152 (화정동)  광주광역시 2018-04-16    2018       4
# 46              광주광역시 서구 화운로 152 (화정동)  광주광역시 2018-04-16    2018       4
# 47              광주광역시 서구 화운로 152 (화정동)  광주광역시 2018-05-09    2018       5
# ...                                ...    ...        ...     ...     ...
# 18754  경기도 용인시 기흥구 용구대로2469번길 20 (보정동)    경기도 2018-05-31    2018       5
# 18757            부산광역시 해운대구 반여동 1212-2  부산광역시 2018-05-31    2018       5
# 18758            부산광역시 해운대구 반여동 1212-2  부산광역시 2018-05-31    2018       5
# 18761        부산광역시 중구 광복로 96-1 (광복동1가)  부산광역시 2018-05-31    2018       5
# 18762        부산광역시 중구 광복로 96-1 (광복동1가)  부산광역시 2018-05-31    2018       5
#
#        주문일시_일  주문일시_분기  연령대
# 4          12        2  40대
# 5          12        2  40대
# 45         16        2  40대
# 46         16        2  40대
# 47          9        2  40대
# ...       ...      ...  ...
# 18754      31        2  30대
# 18757      31        2  40대
# 18758      31        2  40대
# 18761      31        2  40대
# 18762      31        2  40대
#
# [5161 rows x 43 columns]

# %%
df18.pivot_table(index='주문일시_월', values='판매가', aggfunc='sum')
# Out:
#               판매가
# 주문일시_월
# 1        33937280
# 2        25279010
# 3        35709030
# 4        64742940
# 5       105309680

# %%
# 연령대별 판매가 가설검정

stats.normaltest(df18[df18['연령대'].isin(['20대','30대'])]['판매가'])
# p.value < 0.05 / 대립가설 참 / 분포가 정규분포를 따르지 않는다.
# Out:
# NormaltestResult(statistic=567.7912191759135, pvalue=5.078124209512846e-124)

# %%
#     - '판매가'의 정규성을 확인

stats.normaltest(df18['판매가'])
# p.value < 0.05 / 대립가설 참 / 분포가 정규분포를 따르지 않는다.
# Out:
# NormaltestResult(statistic=2119.2300905862367, pvalue=0.0)

# %%
cond18 = df18['연령대'].isin(['20대','30대'])

stats.ranksums(df18.loc[cond18]['판매가'],df18.loc[~cond18]['판매가'])
# P.value < 0.05 / 대립가설 참 / 두 집단의 판매가 값의 평균의 차이가 있다.
# Out:
# RanksumsResult(statistic=-2.2966556893942585, pvalue=0.02163841907455147)

# %% [markdown]
# ## 2019년도 별 매출

# %%
# 2019년도 매출로
df19 = df2[df2['주문일시_년']==2019]
df19
# Out:
#                  ID  나이  사용가능 적립금  성별                최종접속일  \
# 63         kyen1311  69      5820  여자  2019-03-24 오후 11:32
# 64         kyen1311  69      5820  여자  2019-03-24 오후 11:32
# 75          xigol80  40      8150  남자   2019-05-03 오전 4:06
# 76          xigol80  40      8150  남자   2019-05-03 오전 4:06
# 77          xigol80  40      8150  남자   2019-05-03 오전 4:06
# ...             ...  ..       ...  ..                  ...
# 43518  1094652352@k  47       700  남자  2019-05-31 오전 10:05
# 43519  1094746791@k  47      1200  남자   2019-05-31 오후 5:00
# 43520  1094746791@k  47      1200  남자   2019-05-31 오후 5:00
# 43521    51775030@n  45       600  남자   2019-05-31 오후 2:41
# 43522        pp1730  31      1000  남자   2019-05-31 오후 4:38
#
#                      최종주문일     유입경로 유입기기      회원 가입일 사업자구분     회원구분  \
# 63     2019-03-24 오후 11:37     신문광고   PC  2017-03-03   사업자      사업자
# 64     2019-03-24 오후 11:37     신문광고   PC  2017-03-03   사업자      사업자
# 75      2019-05-03 오전 4:09  인터넷기사광고   PC  2017-03-08   사업자      사업자
# 76      2019-05-03 오전 4:09  인터넷기사광고   PC  2017-03-08   사업자      사업자
# 77      2019-05-03 오전 4:09  인터넷기사광고   PC  2017-03-08   사업자      사업자
# ...                    ...      ...  ...         ...   ...      ...
# 43518  2019-05-31 오전 10:07    블로그광고   PC  2019-05-31    개인       일반
# 43519   2019-05-31 오후 4:58    SNS광고  모바일  2019-05-31    개인       일반
# 43520   2019-05-31 오후 4:58    SNS광고  모바일  2019-05-31    개인       일반
# 43521   2019-05-31 오후 3:17    SNS광고  모바일  2019-05-31    개인       일반
# 43522   2019-05-31 오후 4:30    유튜브광고   PC  2019-05-31    개인  전화주문 고객
#
#             결제수단      공급원가  교환구분  네이버 포인트                   배송번호 배송비 정보  \
# 63         무통장입금   71500.0  교환안함        0  D-20190114-0000629-00     무료
# 64            카드   71500.0  교환안함        0  D-20190324-0000373-00     무료
# 75     적립금,무통장입금   44000.0  교환안함        0  D-20190209-0000022-00     무료
# 76     적립금,무통장입금   49500.0  교환안함        0  D-20190318-0000031-00     무료
# 77     적립금,무통장입금   44000.0  교환안함        0  D-20190318-0000031-01     무료
# ...          ...       ...   ...      ...                    ...    ...
# 43518     적립금,카드   60500.0  교환안함        0  D-20190531-0000101-00     무료
# 43519         카드  118800.0  교환안함        0  D-20190531-0000551-00     무료
# 43520         카드   92400.0  교환안함        0  D-20190531-0000551-01     무료
# 43521     적립금,카드   47850.0  교환안함        0  D-20190531-0000467-00     무료
# 43522      무통장입금   42900.0  교환안함        0  D-20190531-0000541-00     무료
#
#                     배송시작일               배송완료일  사용한 적립금액  상품구매금액  \
# 63     2019-01-16 오전 9:01  2019-01-20 오전 5:32         0  119020
# 64     2019-03-25 오후 6:21  2019-03-29 오전 5:32         0   91620
# 75     2019-02-11 오후 6:58  2019-02-15 오전 5:32     36000  141240
# 76     2019-03-19 오전 9:13  2019-03-23 오전 5:32     13600   65470
# 77     2019-03-19 오전 9:13  2019-03-23 오전 5:32     13600   60720
# ...                   ...                 ...       ...     ...
# 43518  2019-05-31 오후 6:11  2019-06-04 오전 5:32      1000   77000
# 43519  2019-06-03 오후 6:08  2019-06-07 오전 5:32         0  167640
# 43520  2019-06-03 오후 6:08  2019-06-07 오전 5:32         0  132360
# 43521  2019-06-03 오후 6:08  2019-06-07 오전 5:32      1000   61900
# 43522  2019-06-03 오후 6:08  2019-06-07 오전 5:32         0   55870
#
#                                                   상품명    상품번호  상품별 추가할인금액  수량  \
# 63                      사각 죽용기 소 550ml 500개 1set(2박스)    88.0       27400   1
# 64                      사각 죽용기 소 550ml 500개 1set(2박스)    88.0           0   1
# 75     95파이 다용도컵 세트 4호 소 200ml 백색 PS 1,000개 1set(2박스)    42.0       19800   2
# 76      70파이 다용도컵 세트 2호 대 80ml 백색 PS 3,000개 1set(2박스)    39.0           0   1
# 77     95파이 다용도컵 세트 4호 소 200ml 백색 PS 1,000개 1set(2박스)    42.0           0   1
# ...                                               ...     ...         ...  ..
# 43518                    친환경 일체형 펄프용기 B003 500개(1BOX)  1555.0        3800   1
# 43519                   포기김치용기 투명 100개 1set(2박스/6.5L)  1354.0           0   1
# 43520                  물김치용기 투명 100개 1set(2박스/직사각 5L)  1353.0           0   1
# 43521                      195파이 탕용기 대 300개 1set(2박스)   608.0           0   1
# 43522   70파이 다용도컵 세트 1호 소 70ml 백색 PS 3,000개 1set(2박스)    38.0           0   1
#
#                            수령인 주소 주문 시 회원등급   주문경로              주문번호  \
# 63       충청북도 청주시 서원구 남이면 가마3길 48       사업자  PC쇼핑몰  20190114-0000629
# 64       충청북도 청주시 서원구 남이면 가마3길 48       사업자  PC쇼핑몰  20190324-0000373
# 75                서울특별시 영등포구 여의도동       사업자  PC쇼핑몰  20190209-0000022
# 76                서울특별시 영등포구 여의도동       사업자  PC쇼핑몰  20190318-0000031
# 77                서울특별시 영등포구 여의도동       사업자  PC쇼핑몰  20190318-0000031
# ...                           ...       ...    ...               ...
# 43518    전라북도 전주시 덕진구 출판로 43 (장동)        일반  PC쇼핑몰  20190531-0000101
# 43519   충청남도 공주시 한적2길 64-13 (금흥동)        일반   모바일웹  20190531-0000551
# 43520   충청남도 공주시 한적2길 64-13 (금흥동)        일반   모바일웹  20190531-0000551
# 43521       대전광역시 서구 도솔로 41 (도마동)        일반   모바일웹  20190531-0000467
# 43522  경기도 의정부시 동일로454번길 40 (신곡동)   전화주문 고객  PC쇼핑몰  20190531-0000541
#
#                       주문일시      카드사  쿠폰 할인금액     판매가   품목번호 결제수단_cut  \
# 63      2019-01-14 오후 2:52     카드아님        0  119020  46242    무통장입금
# 64     2019-03-24 오후 11:37       현대        0   91620  63017       카드
# 75      2019-02-09 오전 3:32     카드아님        0   70620  51896    무통장입금
# 76      2019-03-18 오전 1:57     카드아님        0   65470  61271    무통장입금
# 77      2019-03-18 오전 1:57     카드아님        0   60720  61272    무통장입금
# ...                    ...      ...      ...     ...    ...      ...
# 43518  2019-05-31 오전 10:07       국민        0   77000  79647       카드
# 43519   2019-05-31 오후 4:58  NH (농협)        0  167640  79776       카드
# 43520   2019-05-31 오후 4:58  NH (농협)        0  132360  79777       카드
# 43521   2019-05-31 오후 3:17  NH (농협)        0   61900  79743       카드
# 43522   2019-05-31 오후 4:30     카드아님        0   55870  79774    무통장입금
#
#                                주소     시도    주문일시_dt  주문일시_년  주문일시_월  주문일시_일  \
# 63       충청북도 청주시 서원구 남이면 가마3길 48   충청북도 2019-01-14    2019       1      14
# 64       충청북도 청주시 서원구 남이면 가마3길 48   충청북도 2019-03-24    2019       3      24
# 75                서울특별시 영등포구 여의도동  서울특별시 2019-02-09    2019       2       9
# 76                서울특별시 영등포구 여의도동  서울특별시 2019-03-18    2019       3      18
# 77                서울특별시 영등포구 여의도동  서울특별시 2019-03-18    2019       3      18
# ...                           ...    ...        ...     ...     ...     ...
# 43518    전라북도 전주시 덕진구 출판로 43 (장동)   전라북도 2019-05-31    2019       5      31
# 43519   충청남도 공주시 한적2길 64-13 (금흥동)   충청남도 2019-05-31    2019       5      31
# 43520   충청남도 공주시 한적2길 64-13 (금흥동)   충청남도 2019-05-31    2019       5      31
# 43521       대전광역시 서구 도솔로 41 (도마동)  대전광역시 2019-05-31    2019       5      31
# 43522  경기도 의정부시 동일로454번길 40 (신곡동)    경기도 2019-05-31    2019       5      31
#
#        주문일시_분기  연령대
# 63           1  60대
# 64           1  60대
# 75           1  40대
# 76           1  40대
# 77           1  40대
# ...        ...  ...
# 43518        2  40대
# 43519        2  40대
# 43520        2  40대
# 43521        2  40대
# 43522        2  30대
#
# [16494 rows x 43 columns]

# %%
df19.pivot_table(index='주문일시_월', values='판매가', aggfunc='sum')
# Out:
#               판매가
# 주문일시_월
# 1       251804130
# 2       191546700
# 3       211737370
# 4       235040550
# 5       218907630

# %%
#     - '판매가'의 정규성을 확인

stats.normaltest(df19['판매가'])
# p.value > 0.05 / 대립가설 참 / 분포가 정규분포를 따르지 않는다.
# Out:
# NormaltestResult(statistic=19816.77470636672, pvalue=0.0)

# %%
cond19 = df19['연령대'].isin(['20대','30대'])

stats.ranksums(df19.loc[cond19]['판매가'],df19.loc[~cond19]['판매가'])
# P.value > 0.05 / 귀무가설 참 / 두 집단의 판매가 값의 평균의 차이가 없다.
# Out:
# RanksumsResult(statistic=-0.6689526725280561, pvalue=0.5035256686923594)

# %% [markdown]
# # restart

# %%
def func(row):
    if 20<=row<=23:
        return '20대초반'
    elif 24<=row<=26:
        return '20대중반'
    elif 27<=row<=29:
        return '20대후반'
    elif 30<=row<=33:
        return '30대초반'
    elif 34<=row<=36:
        return '30대중반'
    elif 37<=row<=39:
        return '30대후반'
    elif 40<=row<50:
        return '40대'
    elif 50<=row<60:
        return '50대'
    elif 60<=row<70:
        return '60대'
    elif 70<=row<80:
        return '70대'
    elif 80<=row<90:
        return '80대'
    elif 90<=row:
        return '90대'

df['연령대'] = df['나이'].apply(func)

# %%
df.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '최종접속일', '최종주문일', '유입경로', '유입기기',
#        '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트', '배송번호',
#        '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가', '품목번호', '결제수단_cut', '주소', '시도', '주문일시_dt',
#        '주문일시_년', '주문일시_월', '주문일시_일', '주문일시_분기', '연령대'],
#       dtype='object')

# %%
print(stats.normaltest(df.loc[df['연령대']=='20대초반']['판매가']))
print(stats.normaltest(df.loc[df['연령대']=='20대중반']['판매가']))
print(stats.normaltest(df.loc[df['연령대']=='20대후반']['판매가']))
print(stats.normaltest(df.loc[df['연령대']=='30대초반']['판매가']))
print(stats.normaltest(df.loc[df['연령대']=='30대중반']['판매가']))
print(stats.normaltest(df.loc[df['연령대']=='30대후반']['판매가']))
# Out:
# NormaltestResult(statistic=2263.791930502665, pvalue=0.0)
# NormaltestResult(statistic=18.494942600108345, pvalue=9.635499713442331e-05)
# NormaltestResult(statistic=6.703464564177024, pvalue=0.035023630712852714)
# NormaltestResult(statistic=519.545759250804, pvalue=1.5207990430111337e-113)
# NormaltestResult(statistic=1230.3335722493962, pvalue=6.862136234490152e-268)
# NormaltestResult(statistic=1406.5544302844237, pvalue=3.7203707004027243e-306)

# %%
df['연령대'].value_counts().index
age_list = ['20대초반', '20대중반', '20대후반', '30대초반', '30대중반', '30대후반']
df_a = df[df['연령대'].isin(age_list)]

# %%
df_a_m = df_a.pivot_table(index='연령대', values='판매가',columns='주문일시_년', aggfunc='sum').reset_index()
df_a_m
# Out:
# 주문일시_년    연령대     2017       2018       2019
# 0       20대중반  1860630   64289620   67156520
# 1       20대초반   624220   60934390   60345850
# 2       20대후반  2736830   85235450   89237220
# 3       30대중반  5031420   77046520   56902780
# 4       30대초반  7554070  153990980  117552050
# 5       30대후반  3635140   64912890   55058070

# %%
sns.barplot(data=df_a, x='연령대', y='판매가', ci=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.barplot(data=df_a_m, x='연령대', y=2017, ci=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.barplot(data=df_a_m, x='연령대', y=2018, ci=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.barplot(data=df_a_m, x='연령대', y=2019, ci=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52488 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 2017

# %%
df_17 = df[df['주문일시_년']==2017]

# %%
print(stats.normaltest(df_17.loc[df_17['연령대']=='20대초반']['판매가'])) # F
print(stats.normaltest(df_17.loc[df_17['연령대']=='20대중반']['판매가'])) # F
print(stats.normaltest(df_17.loc[df_17['연령대']=='20대후반']['판매가'])) # F
print(stats.normaltest(df_17.loc[df_17['연령대']=='30대초반']['판매가'])) # F
print(stats.normaltest(df_17.loc[df_17['연령대']=='30대중반']['판매가'])) # T
print(stats.normaltest(df_17.loc[df_17['연령대']=='30대후반']['판매가'])) # F
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/stats/stats.py:1542: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   "anyway, n=%i" % int(n))
# NormaltestResult(statistic=19.529252868180404, pvalue=5.744822594722311e-05)
# NormaltestResult(statistic=15.796067613373308, pvalue=0.00037147321103093447)
# NormaltestResult(statistic=12.212087372829068, pvalue=0.002229353409580982)
# NormaltestResult(statistic=926.4583354683037, pvalue=6.639396366162164e-202)
# NormaltestResult(statistic=2.5057453027641583, pvalue=0.28568294946521045)
# NormaltestResult(statistic=10.215771579069914, pvalue=0.006048857973097593)

# %% [markdown]
# ## 2018

# %%
df_18 = df[df['주문일시_년']==2018]

# %%
print(stats.normaltest(df_18.loc[df_18['연령대']=='20대초반']['판매가'])) # F
print(stats.normaltest(df_18.loc[df_18['연령대']=='20대중반']['판매가'])) # F
print(stats.normaltest(df_18.loc[df_18['연령대']=='20대후반']['판매가'])) # F
print(stats.normaltest(df_18.loc[df_18['연령대']=='30대초반']['판매가'])) # F
print(stats.normaltest(df_18.loc[df_18['연령대']=='30대중반']['판매가'])) # F
print(stats.normaltest(df_18.loc[df_18['연령대']=='30대후반']['판매가'])) # F
# Out:
# NormaltestResult(statistic=224.13677346585044, pvalue=2.134607574183215e-49)
# NormaltestResult(statistic=293.55873296591363, pvalue=1.796929668343037e-64)
# NormaltestResult(statistic=194.91129407623066, pvalue=4.73751132368121e-43)
# NormaltestResult(statistic=262.25569809171174, pvalue=1.12693465814926e-57)
# NormaltestResult(statistic=778.8878081677492, pvalue=7.356334105124747e-170)
# NormaltestResult(statistic=837.7372585839978, pvalue=1.2236737848430397e-182)

# %% [markdown]
# ## 2019

# %%
df_19 = df[df['주문일시_년']==2019]

# %%
print(stats.normaltest(df_19.loc[df_19['연령대']=='20대초반']['판매가'])) # F
print(stats.normaltest(df_19.loc[df_19['연령대']=='20대중반']['판매가'])) # F
print(stats.normaltest(df_19.loc[df_19['연령대']=='20대후반']['판매가'])) # F
print(stats.normaltest(df_19.loc[df_19['연령대']=='30대초반']['판매가'])) # F
print(stats.normaltest(df_19.loc[df_19['연령대']=='30대중반']['판매가'])) # F
print(stats.normaltest(df_19.loc[df_19['연령대']=='30대후반']['판매가'])) # F
# Out:
# NormaltestResult(statistic=1706.2093220749744, pvalue=0.0)
# NormaltestResult(statistic=122.82500022640446, pvalue=2.1325051121488083e-27)
# NormaltestResult(statistic=268.2245193606879, pvalue=5.698829519540133e-59)
# NormaltestResult(statistic=710.2714055069164, pvalue=5.8414944356457705e-155)
# NormaltestResult(statistic=102.25694179081668, pvalue=6.240037821212477e-23)
# NormaltestResult(statistic=657.8138110021578, pvalue=1.4372948882438825e-143)

# %% [markdown]
# # 데이터 3개 병합

# %%
print(master_member.columns)

print(master_product.columns)

print(log_order.columns)
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '주소(동/읍/면)', '최종접속일', '최종주문일', '유입경로',
#        '유입기기', '회원 가입일', '사업자구분', '회원구분'],
#       dtype='object')
# Index(['#', '공급사', '과세/면세', '담기', '매입가', '상품명(기본)', '상품코드', '재입고알림', '제조사',
#        '카테고리', '판매가', '품절여부', '후기'],
#       dtype='object')
# Index(['결제수단', '공급원가', '교환구분', '네이버 포인트', '배송번호', '배송비 정보', '배송시작일', '배송완료일',
#        '사용한 적립금액', '상품구매금액', '상품명', '상품번호', '상품별 추가할인금액', '수량', '수령인 주소',
#        '주문 시 회원등급', '주문경로', '주문번호', '주문일시', 'ID', '카드사', '쿠폰 할인금액', '판매가',
#        '품목번호'],
#       dtype='object')

# %%
df2 = pd.merge(master_member, log_order, left_on='ID', right_on='ID', how='inner')
df3 = pd.merge(df2, master_product, left_on='상품번호', right_on='상품코드', how='inner')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30718 entries, 0 to 30717
# Data columns (total 48 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          30718 non-null  object
#  1   나이          30718 non-null  int64
#  2   사용가능 적립금    30718 non-null  int64
#  3   성별          30718 non-null  object
#  4   주소(동/읍/면)   30463 non-null  object
#  5   최종접속일       30718 non-null  object
#  6   최종주문일       30718 non-null  object
#  7   유입경로        30718 non-null  object
#  8   유입기기        30718 non-null  object
#  9   회원 가입일      30718 non-null  object
#  10  사업자구분       30718 non-null  object
#  11  회원구분        30718 non-null  object
#  12  결제수단        30718 non-null  object
#  13  공급원가        30718 non-null  float64
#  14  교환구분        30718 non-null  object
#  15  네이버 포인트     30718 non-null  int64
#  16  배송번호        30718 non-null  object
#  17  배송비 정보      30718 non-null  object
#  18  배송시작일       30718 non-null  object
#  19  배송완료일       30718 non-null  object
#  20  사용한 적립금액    30718 non-null  int64
#  21  상품구매금액      30718 non-null  int64
#  22  상품명         30718 non-null  object
#  23  상품번호        30718 non-null  float64
#  24  상품별 추가할인금액  30718 non-null  int64
#  25  수량          30718 non-null  int64
#  26  수령인 주소      30718 non-null  object
#  27  주문 시 회원등급   30718 non-null  object
#  28  주문경로        30718 non-null  object
#  29  주문번호        30718 non-null  object
#  30  주문일시        30718 non-null  object
#  31  카드사         10465 non-null  object
#  32  쿠폰 할인금액     30718 non-null  int64
#  33  판매가_x       30718 non-null  int64
#  34  품목번호        30718 non-null  int64
#  35  #           30718 non-null  int64
#  36  공급사         30718 non-null  object
#  37  과세/면세       30718 non-null  object
#  38  담기          30718 non-null  int64
#  39  매입가         30718 non-null  int64
#  40  상품명(기본)     30718 non-null  object
#  41  상품코드        30718 non-null  int64
#  42  재입고알림       30718 non-null  object
#  43  제조사         30697 non-null  object
#  44  카테고리        30718 non-null  object
#  45  판매가_y       30718 non-null  int64
#  46  품절여부        30718 non-null  object
#  47  후기          30718 non-null  int64
# dtypes: float64(2), int64(16), object(30)
# memory usage: 11.5+ MB

# %%
df3.isnull().sum()
# Out:
# ID                0
# 나이                0
# 사용가능 적립금          0
# 성별                0
# 주소(동/읍/면)       255
# 최종접속일             0
# 최종주문일             0
# 유입경로              0
# 유입기기              0
# 회원 가입일            0
# 사업자구분             0
# 회원구분              0
# 결제수단              0
# 공급원가              0
# 교환구분              0
# 네이버 포인트           0
# 배송번호              0
# 배송비 정보            0
# 배송시작일             0
# 배송완료일             0
# 사용한 적립금액          0
# 상품구매금액            0
# 상품명               0
# 상품번호              0
# 상품별 추가할인금액        0
# 수량                0
# 수령인 주소            0
# 주문 시 회원등급         0
# 주문경로              0
# 주문번호              0
# 주문일시              0
# 카드사           20253
# 쿠폰 할인금액           0
# 판매가_x             0
# 품목번호              0
# #                 0
# 공급사               0
# 과세/면세             0
# 담기                0
# 매입가               0
# 상품명(기본)           0
# 상품코드              0
# 재입고알림             0
# 제조사              21
# 카테고리              0
# 판매가_y             0
# 품절여부              0
# 후기                0
# dtype: int64

# %%
df3['카드사'] = df3['카드사'].fillna('카드아님')

# %%
df3.isnull().sum()
# Out:
# ID              0
# 나이              0
# 사용가능 적립금        0
# 성별              0
# 주소(동/읍/면)     255
# 최종접속일           0
# 최종주문일           0
# 유입경로            0
# 유입기기            0
# 회원 가입일          0
# 사업자구분           0
# 회원구분            0
# 결제수단            0
# 공급원가            0
# 교환구분            0
# 네이버 포인트         0
# 배송번호            0
# 배송비 정보          0
# 배송시작일           0
# 배송완료일           0
# 사용한 적립금액        0
# 상품구매금액          0
# 상품명             0
# 상품번호            0
# 상품별 추가할인금액      0
# 수량              0
# 수령인 주소          0
# 주문 시 회원등급       0
# 주문경로            0
# 주문번호            0
# 주문일시            0
# 카드사             0
# 쿠폰 할인금액         0
# 판매가_x           0
# 품목번호            0
# #               0
# 공급사             0
# 과세/면세           0
# 담기              0
# 매입가             0
# 상품명(기본)         0
# 상품코드            0
# 재입고알림           0
# 제조사            21
# 카테고리            0
# 판매가_y           0
# 품절여부            0
# 후기              0
# dtype: int64

# %%
df3[df3['주소(동/읍/면)'].isna()]
# Out:
#                  ID  나이  사용가능 적립금  성별 주소(동/읍/면)                최종접속일  \
# 360     144151978@n  46      3300  남자       NaN   2019-03-15 오후 8:56
# 376      76136945@n  47       600  남자       NaN  2019-04-16 오전 10:02
# 383      39782363@n  41      2100  남자       NaN  2019-05-08 오전 11:23
# 695    1075139712@k  47       100  남자       NaN   2019-04-30 오후 5:13
# 697      66860271@n  48      3000  남자       NaN   2019-05-13 오후 9:23
# ...             ...  ..       ...  ..       ...                  ...
# 30682    30988933@n  44      1500  남자       NaN   2019-05-21 오후 2:33
# 30704    28023986@n  30       500  남자       NaN   2019-05-30 오후 7:43
# 30706    42406456@n  44      2600  남자       NaN   2019-05-29 오후 1:35
# 30715    90994631@n  48      3200  남자       NaN   2019-05-21 오전 7:53
# 30717  1094746791@k  47      1200  남자       NaN   2019-05-31 오후 5:00
#
#                      최종주문일    유입경로 유입기기      회원 가입일 사업자구분 회원구분       결제수단  \
# 360     2019-03-13 오후 5:09   SNS광고  모바일  2019-03-13    개인   일반      무통장입금
# 376    2019-04-16 오전 10:53   SNS광고  모바일  2019-04-16    개인   일반  적립금,무통장입금
# 383    2019-05-08 오전 11:29   SNS광고  모바일  2019-04-30    개인   일반      무통장입금
# 695     2019-04-30 오후 5:17   SNS광고  모바일  2019-04-30    개인   일반     적립금,카드
# 697     2019-05-13 오후 9:35   블로그광고   PC  2019-05-13    개인   일반      무통장입금
# ...                    ...     ...  ...         ...   ...  ...        ...
# 30682   2019-05-21 오후 2:39   SNS광고  모바일  2019-05-09    개인   일반      무통장입금
# 30704   2019-05-30 오후 7:49  카카오톡광고  모바일  2019-04-04    개인   일반     적립금,카드
# 30706   2019-05-29 오후 1:48   블로그광고   PC  2019-04-10    개인   일반         카드
# 30715   2019-05-21 오전 7:55   블로그광고  모바일  2019-05-21    개인   일반      무통장입금
# 30717   2019-05-31 오후 4:58   SNS광고  모바일  2019-05-31    개인   일반         카드
#
#            공급원가  교환구분  네이버 포인트                   배송번호 배송비 정보  \
# 360     51700.0  교환안함        0  D-20190313-0000943-00     무료
# 376     51700.0  교환안함        0  D-20190416-0000202-00     무료
# 383     51700.0  교환안함        0  D-20190508-0000359-00     무료
# 695     84700.0  교환안함        0  D-20190430-0001051-00     무료
# 697     84700.0  교환안함        0  D-20190513-0001107-00     무료
# ...         ...   ...      ...                    ...    ...
# 30682   12680.0  교환안함        0  D-20190521-0000608-02     무료
# 30704   14520.0  교환안함        0  D-20190404-0000578-00     무료
# 30706   35200.0  교환안함        0  D-20190507-0001481-00     무료
# 30715   77550.0  교환안함        0  D-20190521-0000037-00     무료
# 30717  118800.0  교환안함        0  D-20190531-0000551-00     무료
#
#                      배송시작일               배송완료일  사용한 적립금액  상품구매금액  \
# 360    2019-03-15 오전 10:12  2019-03-19 오전 5:32         0   64070
# 376     2019-04-16 오후 6:26  2019-04-20 오전 5:32      1000   64070
# 383     2019-05-09 오후 6:32  2019-05-13 오전 5:32         0   64070
# 695    2019-05-03 오전 11:13  2019-05-07 오전 5:32      1000  107970
# 697     2019-05-14 오후 6:51  2019-05-18 오전 5:32         0  107970
# ...                    ...                 ...       ...     ...
# 30682  2019-05-24 오전 10:17  2019-05-28 오전 5:32         0   21000
# 30704  2019-04-05 오후 12:07  2019-04-09 오전 5:32      1000   27100
# 30706  2019-05-09 오전 11:07  2019-05-13 오전 5:32         0   46000
# 30715   2019-05-22 오전 9:11  2019-05-26 오전 5:32         0  231600
# 30717   2019-06-03 오후 6:08  2019-06-07 오전 5:32         0  167640
#
#                                                    상품명    상품번호  상품별 추가할인금액  \
# 360    105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45.0           0
# 376    105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45.0           0
# 383    105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45.0           0
# 695                    사각 찜용기 대 3,200ml 200개 1set(2박스)    72.0           0
# 697                    사각 찜용기 대 3,200ml 200개 1set(2박스)    72.0           0
# ...                                                ...     ...         ...
# 30682                                생수1800  60개(1BOX)  1439.0           0
# 30704                             목향 양념단지 2호 10개(1BOX)  1522.0           0
# 30706                         무지 종이용기 850ml 500개(1BOX)  1567.0        5010
# 30715                    실링용기 36호 반투명 7,000ml 300개 1박스   939.0           0
# 30717                    포기김치용기 투명 100개 1set(2박스/6.5L)  1354.0           0
#
#        수량                        수령인 주소 주문 시 회원등급   주문경로              주문번호  \
# 360     1         울산광역시 남구 대학로 32 (무거동)        일반   모바일웹  20190313-0000943
# 376     1        경상남도 양산시 고연로 283 (용당동)        일반   모바일웹  20190416-0000202
# 383     1            울산광역시 남구 무거동 491-1        일반   모바일웹  20190508-0000359
# 695     1        대전광역시 유성구 원내로 28 (원내동)        일반   모바일웹  20190430-0001051
# 697     1                 서울특별시 서초구 양재동        일반  PC쇼핑몰  20190513-0001107
# ...    ..                           ...       ...    ...               ...
# 30682   1    울산광역시 울주군 온양읍 화산발리로 742-10        일반   모바일웹  20190521-0000608
# 30704   1  부산광역시 사하구 낙동대로199번길 16 (괴정동)        일반   모바일웹  20190404-0000578
# 30706   1      울산광역시 북구 명촌1길 14-2 (진장동)        일반  PC쇼핑몰  20190507-0001481
# 30715   2      경상남도 통영시 광도면 향교옆길 144-17        일반   모바일웹  20190521-0000037
# 30717   1     충청남도 공주시 한적2길 64-13 (금흥동)        일반   모바일웹  20190531-0000551
#
#                       주문일시      카드사  쿠폰 할인금액   판매가_x   품목번호     #      공급사  \
# 360     2019-03-13 오후 5:09     카드아님        0   64070  60438  1013      패커스
# 376    2019-04-16 오전 10:53     카드아님        0   64070  68685  1013      패커스
# 383    2019-05-08 오전 11:29     카드아님        0   64070  74236  1013      패커스
# 695     2019-04-30 오후 5:17       외환        0  107970  72367  1003      패커스
# 697     2019-05-13 오후 9:35     카드아님        0  107970  75512  1003      패커스
# ...                    ...      ...      ...     ...    ...   ...      ...
# 30682   2019-05-21 오후 2:39     카드아님        0   21000  77353   633      패커스
# 30704  2019-04-04 오후 12:34       삼성        0   27100  66077   572  다이찌롱스토어
# 30706   2019-05-07 오후 6:23       삼성        0   46000  74071   545      패커스
# 30715   2019-05-21 오전 7:55     카드아님        0  115800  77172   843      패커스
# 30717   2019-05-31 오후 4:58  NH (농협)        0  167640  79776   689      패커스
#
#       과세/면세  담기     매입가                                          상품명(기본)  \
# 360      과세  17   51700  105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)
# 376      과세  17   51700  105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)
# 383      과세  17   51700  105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)
# 695      과세   3   34650                   사각찜용기 대 3,200ml 100개 1set(2박스)
# 697      과세   3   34650                   사각찜용기 대 3,200ml 100개 1set(2박스)
# ...     ...  ..     ...                                              ...
# 30682    과세   0   12680                                 생수1800 60개(1BOX)
# 30704    과세   0   14520                             목향 양념단지 2호 10개(1BOX)
# 30706    과세   2   40700                       친환경 펄프접시 P004 1,000개(1BOX)
# 30715    과세   0   77550                    실링용기 36호 반투명 7,000ml 300개 1박스
# 30717    과세   0  118800                 포기김치용기 투명 100개 1set(2박스/직사각6.5L)
#
#        상품코드 재입고알림   제조사                                               카테고리  \
# 360      45   사용함  자체제작  039 : 중식 용기\n039003 : 중식 용기 > 소스/국/밥용기\n040 : ...
# 376      45   사용함  자체제작  039 : 중식 용기\n039003 : 중식 용기 > 소스/국/밥용기\n040 : ...
# 383      45   사용함  자체제작  039 : 중식 용기\n039003 : 중식 용기 > 소스/국/밥용기\n040 : ...
# 695      72   사용함  자체제작  038 : 한식(분식) 용기\n038001 : 한식(분식) 용기 > 탕/찜/죽/면용...
# 697      72   사용함  자체제작  038 : 한식(분식) 용기\n038001 : 한식(분식) 용기 > 탕/찜/죽/면용...
# ...     ...   ...   ...                                                ...
# 30682  1439   사용함  자체제작  043 : 베이커리/카페 용기\n043004 : 베이커리/카페 용기 > 생수/쥬스/...
# 30704  1522   사용함  자체제작  046 : 주방용품/소모품\n046007 : 주방용품/소모품 > 주방용품\n0460...
# 30706  1567   사용함  자체제작  026 : NEW\n026002 : NEW > 펄프용기\n038 : 한식(분식) 용...
# 30715   939   사용함  자체제작  018 : 실링용기\n018003 : 실링용기 > 실링특대형\n042 : 실링제품\...
# 30717  1354   사용함  자체제작  038 : 한식(분식) 용기\n038003 : 한식(분식) 용기 > 떡/반찬용기\n...
#
#         판매가_y 품절여부  후기
# 360     64070   정상  30
# 376     64070   정상  30
# 383     64070   정상  30
# 695     59600   정상   1
# 697     59600   정상   1
# ...       ...  ...  ..
# 30682   21000   정상   0
# 30704   18000   정상   0
# 30706   56300   품절   0
# 30715  115800   정상   0
# 30717  167640   정상   0
#
# [255 rows x 48 columns]

# %%
df3.loc[df3['주소(동/읍/면)'].isna()]['주소(동/읍/면)'] = df3.loc[df3['주소(동/읍/면)'].isna()]['수령인 주소']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3.loc[df3['주소(동/읍/면)'].isna()]['주소(동/읍/면)'].iloc[0]
df3.loc[df3['주소(동/읍/면)'].isna()]['수령인 주소'].iloc[0]

len(df3.loc[df3['주소(동/읍/면)'].isna()])
# Out:
# 255

# %%
for i in range(len(df3.loc[df3['주소(동/읍/면)'].isna()])) : 
    df3.loc[df3['주소(동/읍/면)'].isna()]['주소(동/읍/면)'].iloc[i] = df3.loc[df3['주소(동/읍/면)'].isna()]['수령인 주소'].iloc[i]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df3.loc[df3['주소(동/읍/면)'].isna()]['주소(동/읍/면)'] = df3.loc[df3['주소(동/읍/면)'].isna()]['수령인 주소']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3 = df3.dropna()

# %%
def func(row):
        if row<30:
                return '20대'
        elif 30<=row<40:
                return '30대'
        elif 40<=row<50:
                return '40대'
        elif 50<=row<60:
                return '50대'
        elif 60<=row<70:
                return '60대'
        elif 70<=row<80:
                return '70대'
        elif 80<=row<90:
                return '80대'
        elif 90<=row:
                return '90대'

df3['연령대'] = df3['나이'].apply(func)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def func(data):
    return data.split(' ')[0]

df3['주문일시_dt'] = pd.to_datetime(df3['주문일시'].apply(func))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df3['주문일시_년'] = df3['주문일시_dt'].dt.year
df3['주문일시_월'] = df3['주문일시_dt'].dt.month
df3['주문일시_일'] = df3['주문일시_dt'].dt.day
df3['주문일시_분기'] = df3['주문일시_dt'].dt.quarter
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def func4(data) : 
    return data.split(' ')[0]

df3['배송시작일_dt'] = pd.to_datetime(df3['배송시작일'].apply(func4))
df3['배송완료일_dt'] = pd.to_datetime(df3['배송완료일'].apply(func4))

# %%
df3['배송시간'] = df3['배송완료일_dt'] - df3['배송시작일_dt']
df3['배송시간']
# Out:
# 0        0 days
# 1        2 days
# 2        4 days
# 3       10 days
# 4        2 days
#           ...
# 30710    4 days
# 30712    4 days
# 30713    4 days
# 30714    4 days
# 30716    4 days
# Name: 배송시간, Length: 30443, dtype: timedelta64[ns]

# %%
def func3(row):
        row = row.split(' ')[0]
        return row
    
df3['시도'] = df3['수령인 주소'].apply(func3)

# %%
def func6(data) : 
    if data < 100000 :
        return '1만원대'
    else : 
        return '10만원대'

df3['가격대'] = df3['판매가_x'].apply(func6)

# %%
df3_m = df3[df3['연령대'].isin(['20대','30대'])]

# %%
df3_m.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '주소(동/읍/면)', '최종접속일', '최종주문일', '유입경로',
#        '유입기기', '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트',
#        '배송번호', '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가_x', '품목번호', '#', '공급사', '과세/면세', '담기', '매입가',
#        '상품명(기본)', '상품코드', '재입고알림', '제조사', '카테고리', '판매가_y', '품절여부', '후기', '연령대',
#        '주문일시_dt', '주문일시_년', '주문일시_월', '주문일시_일', '주문일시_분기', '배송시작일_dt',
#        '배송완료일_dt', '배송시간', '시도', '가격대'],
#       dtype='object')

# %% [markdown]
# # 모델링

# %%
# 2. 지도학습에 필요한 라이브러리를 호출
from sklearn.model_selection import train_test_split
from sklearn.compose        import make_column_transformer
from sklearn.impute import KNNImputer
from imblearn.pipeline      import pipeline
from imblearn.pipeline      import make_pipeline
from sklearn.impute         import SimpleImputer, KNNImputer
from sklearn.preprocessing  import MinMaxScaler, OneHotEncoder
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import ADASYN
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV    # 교차검증
from sklearn.metrics   import classification_report     # 평가
import pickle
from sklearn.metrics import r2_score, mean_squared_error

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor # Bagging Model 
from sklearn.tree import DecisionTreeClassifier

# %%
df3_m.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '주소(동/읍/면)', '최종접속일', '최종주문일', '유입경로',
#        '유입기기', '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트',
#        '배송번호', '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가_x', '품목번호', '#', '공급사', '과세/면세', '담기', '매입가',
#        '상품명(기본)', '상품코드', '재입고알림', '제조사', '카테고리', '판매가_y', '품절여부', '후기', '연령대',
#        '주문일시_dt', '주문일시_년', '주문일시_월', '주문일시_일', '주문일시_분기', '배송시작일_dt',
#        '배송완료일_dt', '배송시간', '시도', '가격대'],
#       dtype='object')

# %% [markdown]
# ## DecisionTreeClassifier

# %%
df3_m['공급사'].value_counts().index
# Out:
# Index(['패커스', '다이찌롱스토어'], dtype='object')

# %%
df3_m.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '주소(동/읍/면)', '최종접속일', '최종주문일', '유입경로',
#        '유입기기', '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트',
#        '배송번호', '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가_x', '품목번호', '#', '공급사', '과세/면세', '담기', '매입가',
#        '상품명(기본)', '상품코드', '재입고알림', '제조사', '카테고리', '판매가_y', '품절여부', '후기', '연령대',
#        '주문일시_dt', '주문일시_년', '주문일시_월', '주문일시_일', '주문일시_분기', '배송시작일_dt',
#        '배송완료일_dt', '배송시간', '시도', '가격대'],
#       dtype='object')

# %%
len(df3_m['판매가_x'])
# Out:
# 12319

# %%
df3_m['후기'].value_counts()
# Out:
# 10     671
# 0      658
# 71     599
# 9      598
# 68     590
# 96     577
# 67     560
# 2      525
# 80     503
# 6      441
# 1      391
# 18     386
# 37     376
# 174    367
# 17     363
# 43     308
# 30     277
# 3      251
# 4      243
# 39     232
# 14     221
# 79     212
# 8      208
# 26     189
# 38     183
# 11     179
# 15     170
# 22     167
# 60     157
# 5      152
# 44     151
# 32     148
# 19     147
# 46     133
# 20     131
# 16     119
# 25     115
# 51     109
# 50     100
# 47     100
# 7       78
# 34      70
# 12      58
# 31      56
# 24      50
# Name: 후기, dtype: int64

# %% [markdown]
# # Regression

# %%
df3_m.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '주소(동/읍/면)', '최종접속일', '최종주문일', '유입경로',
#        '유입기기', '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트',
#        '배송번호', '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가_x', '품목번호', '#', '공급사', '과세/면세', '담기', '매입가',
#        '상품명(기본)', '상품코드', '재입고알림', '제조사', '카테고리', '판매가_y', '품절여부', '후기', '연령대',
#        '주문일시_dt', '주문일시_년', '주문일시_월', '주문일시_일', '주문일시_분기', '배송시작일_dt',
#        '배송완료일_dt', '배송시간', '시도', '가격대'],
#       dtype='object')

# %%
df3_m['상품별 추가할인금액'].value_counts().index
# Out:
# Int64Index([    0, 15000, 10000, 30000, 14500, 13600,  8800, 17400, 15800,
#             20000,
#             ...
#              2220,  8990, 65000, 36840, 49120, 59400,  6250,  7530, 12700,
#              6010],
#            dtype='int64', length=394)

# %%
df3_m['주문일시_일'].value_counts()

# column 설정할떄 feature importance 알고리즘으로 정하는것, 우리 주관적의견
# Out:
# 7     499
# 15    459
# 28    453
# 23    452
# 14    451
# 8     442
# 26    441
# 11    441
# 13    432
# 30    430
# 29    425
# 21    415
# 3     412
# 22    412
# 10    411
# 18    411
# 2     408
# 27    402
# 12    395
# 19    391
# 20    382
# 17    379
# 25    378
# 24    378
# 9     369
# 4     352
# 5     341
# 16    329
# 6     311
# 1     293
# 31    225
# Name: 주문일시_일, dtype: int64

# %%
X = df3_m[['유입기기','수량','사업자구분','상품별 추가할인금액','제조사','주문일시_월','품절여부']]
Y = df3_m['판매가_x']

# %%
df3_m['회원구분'].value_counts()
# Out:
# 전화주문 고객     5150
# 사업자         5087
# 일반          1831
# 딜러 유치 회원     251
# Name: 회원구분, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state=1234)

numeric_pipe = make_pipeline(SimpleImputer(), StandardScaler())
category_pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), OneHotEncoder())

numeric_list = X.describe().columns.tolist()
category_list = X.describe(include='object').columns.tolist()

preprocessing_pipe = make_column_transformer((numeric_pipe, numeric_list), (category_pipe, category_list))

# %%
preprocessing_pipe
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['수량', '상품별 추가할인금액', '주문일시_월']),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder())]),
#                                  ['유입기기', '사업자구분', '제조사', '품절여부'])])

# %% [markdown]
# ## DecisionTreeRegressor

# %%
model_pipe = make_pipeline(preprocessing_pipe, DecisionTreeRegressor())

hyperparameter_list = {'decisiontreeregressor__max_depth' : range(5,10),
                        'decisiontreeregressor__min_samples_split' : range(5,10),
                        'decisiontreeregressor__min_samples_leaf' : range(5,10)}

grid_model = GridSearchCV(model_pipe, cv=5, param_grid={}, n_jobs=-1)
grid_model.fit(X_train, Y_train)

# 6. 평가
best_model = grid_model.best_estimator_

Y_train_pred = best_model.predict(X_train)
Y_test_pred = best_model.predict(X_test)

print(f'Y_train_pred : {Y_train_pred}\n')
print(f'Y_test_pred : {Y_test_pred}\n')
# 평가
print(f'r2_score_train : {r2_score(Y_train, Y_train_pred)}\n')
print(f'r2_score_test : {r2_score(Y_test, Y_test_pred)}\n')

encoder_list = best_model.named_steps['columntransformer'].transformers_[1][1].named_steps['onehotencoder'].get_feature_names().tolist()
df_importance = pd.DataFrame()
df_importance['Feature'] = pd.Series(numeric_list + encoder_list)

df_importance['Importance']= best_model['decisiontreeregressor'].feature_importances_
df_importance.sort_values(by='Importance', ascending=False)
# Out:
# Y_train_pred : [77370.         67974.75935829 10170.         ... 66603.36158192
#  14660.         63470.        ]
#
# Y_test_pred : [64687.8125     22110.         52360.         ... 52605.58139535
#  60220.32258065 66920.        ]
#
# r2_score_train : 0.6233799052385063
#
# r2_score_test : 0.5215616338823904
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#            Feature  Importance
# 1       상품별 추가할인금액    0.759508
# 0               수량    0.176317
# 2           주문일시_월    0.039179
# 11           x3_정상    0.006886
# 5            x1_개인    0.003892
# 3            x0_PC    0.003851
# 4           x0_모바일    0.003776
# 6           x1_사업자    0.003159
# 10         x2_자체제작    0.002812
# 9    x2_Y-MD-00748    0.000312
# 12           x3_품절    0.000308
# 7    x2_Y-MD-00739    0.000000
# 8   x2_Y-MD-00739★    0.000000

# %% [markdown]
# ## XGBRegressor

# %%
# df_copy = new_df[new_df['판매가'] != 1000000.0]""
# sns.histplot(data=df_copy, x='판매가')

# %%
# 4. 파이프라인을 구성한다.
numeric_pipe = make_pipeline(KNNImputer(), MinMaxScaler())
category_pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), OneHotEncoder())
numeric_list = X.describe().columns.tolist()
category_list = X.describe(include='object').columns.tolist()
preprocessing_pipe = make_column_transformer((numeric_pipe, numeric_list)
                                            , (category_pipe, category_list))
model_pipe = make_pipeline(preprocessing_pipe, XGBRegressor())

hyperparameter_list = {
 'xgbregressor__max_depth':range(5,11),
 'xgbregressor__min_depth':range(5,11)
}

grid_model = GridSearchCV(model_pipe, cv=5, param_grid={}, n_jobs=-1)
grid_model.fit(X_train, Y_train)

# 6. 평가
best_model = grid_model.best_estimator_

Y_train_pred = best_model.predict(X_train)
Y_test_pred = best_model.predict(X_test)


print(f'Y_train_pred : {Y_train_pred}\n')
print(f'Y_test_pred : {Y_test_pred}\n')
# 평가
print(f'r2_score_train : {r2_score(Y_train, Y_train_pred)}\n')
print(f'r2_score_test : {r2_score(Y_test, Y_test_pred)}\n')


encoder_list = best_model.named_steps['columntransformer'].transformers_[1][1].named_steps['onehotencoder'].get_feature_names().tolist()
df_importance = pd.DataFrame()
df_importance['Feature'] = pd.Series(numeric_list + encoder_list)
df_importance['Importance']= best_model['xgbregressor'].feature_importances_
df_importance.sort_values(by='Importance', ascending=False)
# Out:
# [00:21:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Y_train_pred : [64109.055 64313.89  26836.225 ... 64313.89  20891.854 71058.71 ]
#
# Y_test_pred : [71184.81  22925.156 50184.75  ... 54552.277 56635.04  55528.01 ]
#
# r2_score_train : 0.5473787228171285
#
# r2_score_test : 0.5329862539667055
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#            Feature  Importance
# 1       상품별 추가할인금액    0.381117
# 0               수량    0.366100
# 10         x2_자체제작    0.075958
# 11           x3_정상    0.066503
# 2           주문일시_월    0.061708
# 3            x0_PC    0.017373
# 9    x2_Y-MD-00748    0.017109
# 5            x1_개인    0.014132
# 4           x0_모바일    0.000000
# 6           x1_사업자    0.000000
# 7    x2_Y-MD-00739    0.000000
# 8   x2_Y-MD-00739★    0.000000
# 12           x3_품절    0.000000

# %%
df_importance.sort_values(by='Importance', ascending=False).index
# Out:
# Int64Index([1, 0, 10, 11, 2, 3, 9, 5, 4, 6, 7, 8, 12], dtype='int64')

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df_importance.iloc[[1, 0, 11, 10, 9, 2, 3, 5, 7]], x='Feature', y='Importance')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54624 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51089 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54624 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51089 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from xgboost import XGBClassifier

# model = XGBClassifier()
# model.fit(X, Y)

print(best_model['xgbregressor'].feature_importances_)
# plt.bar(range(len(model.feature_importances_)), model.feature_importances_)
# plt.show()
# Out:
# [0.36610043 0.38111725 0.06170751 0.01737308 0.         0.01413196
#  0.         0.         0.         0.01710895 0.07595786 0.06650296
#  0.        ]

# %%
# # xgb 시각화
# from xgboost import plot_importance
# from xgboost import plot_tree
# import matplotlib.pyplot as plt
# %matplotlib inline

# fig, ax = plt.subplots(figsize=(12, 12))
# plot_importance(best_model, ax=ax)

# %% [markdown]
# ## RandomForestRegressor

# %%
# 4. 파이프라인을 구성한다.
numeric_pipe = make_pipeline(KNNImputer(), MinMaxScaler())
category_pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), OneHotEncoder())
numeric_list = X.describe().columns.tolist()
category_list = X.describe(include='object').columns.tolist()
preprocessing_pipe = make_column_transformer((numeric_pipe, numeric_list)
                                            , (category_pipe, category_list))
model_pipe = make_pipeline(preprocessing_pipe, RandomForestRegressor())
# 5. 교차검증 및 하이퍼 파라미터 튜닝
hyperparameter_list = {'randomforestregressor__max_depth':range(5,11)
                        , 'randomforestregressor__min_samples_leaf':range(5,11)
                        , 'randomforestregressor__min_samples_split':range(5,11)}
grid_model = GridSearchCV(model_pipe, param_grid={}
                            , cv=5, n_jobs=-1, scoring='f1')
grid_model.fit(X_train, Y_train)

# 6. 평가
best_model = grid_model.best_estimator_

Y_train_pred = best_model.predict(X_train)
Y_test_pred = best_model.predict(X_test)

print(f'Y_train_pred : {Y_train_pred}\n')
print(f'Y_test_pred : {Y_test_pred}\n')
# 평가
print(f'r2_score_train : {r2_score(Y_train, Y_train_pred)}\n')
print(f'r2_score_test : {r2_score(Y_test, Y_test_pred)}\n')

encoder_list = best_model.named_steps['columntransformer'].transformers_[1][1].named_steps['onehotencoder'].get_feature_names().tolist()
df_importance = pd.DataFrame()
df_importance['Feature'] = pd.Series(numeric_list + encoder_list)


df_importance['Importance']= best_model['randomforestregressor'].feature_importances_
df_importance.sort_values(by='Importance', ascending=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:972: UserWarning: One or more of the test scores are non-finite: [nan]
#   category=UserWarning,
# Y_train_pred : [76848.65       68049.73631444 10812.4        ... 66470.63939726
#  15240.7        63470.        ]
#
# Y_test_pred : [64182.07987235 21629.7        52408.73968254 ... 53197.58743408
#  59238.61579076 53733.19953374]
#
# r2_score_train : 0.619120865334224
#
# r2_score_test : 0.558805822142584
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#            Feature  Importance
# 1       상품별 추가할인금액    0.727626
# 0               수량    0.186473
# 2           주문일시_월    0.054926
# 5            x1_개인    0.005237
# 4           x0_모바일    0.005118
# 6           x1_사업자    0.005084
# 3            x0_PC    0.004913
# 11           x3_정상    0.003907
# 12           x3_품절    0.003578
# 10         x2_자체제작    0.001599
# 9    x2_Y-MD-00748    0.001400
# 8   x2_Y-MD-00739★    0.000095
# 7    x2_Y-MD-00739    0.000045

# %% [markdown]
# ## 모델 평가

# %%
# 6. 평가
best_model = grid_model.best_estimator_

Y_train_pred = best_model.predict(X_train)
Y_test_pred = best_model.predict(X_test)

# 평가
print(r2_score(Y_train, Y_train_pred))
print(r2_score(Y_test, Y_test_pred))
# Out:
# 0.619120865334224
# 0.558805822142584

# %%
encoder_list = best_model.named_steps['columntransformer'].transformers_[1][1].named_steps['onehotencoder'].get_feature_names().tolist()
df_importance = pd.DataFrame()
df_importance['Feature'] = pd.Series(numeric_list + encoder_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Classifier

# %%
from sklearn.model_selection import train_test_split
from imblearn.pipeline import make_pipeline
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.tree   import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
def func6(data) : 
    if data < 100000 :
        return '1만원대'
    else : 
        return '10만원대'

df3_m['가격대'] = df3_m['판매가_x'].apply(func6)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
df3_m.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '주소(동/읍/면)', '최종접속일', '최종주문일', '유입경로',
#        '유입기기', '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트',
#        '배송번호', '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가_x', '품목번호', '#', '공급사', '과세/면세', '담기', '매입가',
#        '상품명(기본)', '상품코드', '재입고알림', '제조사', '카테고리', '판매가_y', '품절여부', '후기', '연령대',
#        '주문일시_dt', '주문일시_년', '주문일시_월', '주문일시_일', '주문일시_분기', '배송시작일_dt',
#        '배송완료일_dt', '배송시간', '시도', '가격대'],
#       dtype='object')

# %%
X = df3_m[['유입기기','수량','사업자구분','상품별 추가할인금액','제조사','주문일시_월','품절여부']]
Y = df3_m['가격대']

# %%
X = df3_m[['유입기기','수량','사업자구분','상품별 추가할인금액','제조사','주문일시_월','주문 시 회원등급','상품코드']]
Y = df3_m['가격대']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, random_state=1234)

numeric_pipe = make_pipeline(SimpleImputer(), StandardScaler())
category_pipe = make_pipeline(SimpleImputer(strategy='most_frequent'), OneHotEncoder())

numeric_list = X.describe().columns.tolist()
category_list = X.describe(include='object').columns.tolist()

preprocessing_pipe = make_column_transformer((numeric_pipe, numeric_list), (category_pipe, category_list))

# %% [markdown]
# ## DecisionClassifier

# %%
# 모델 선언 예시
# model = XGBClassifier(n_estimators=500, learning_rate=0.2, max_depth=4, random_state = 32)


model_pipe = make_pipeline(preprocessing_pipe, DecisionTreeClassifier(criterion = "entropy", max_depth = 2))

hyperparameter_list = {'decisiontreeregressor__max_depth' : range(5,10),
                        'decisiontreeregressor__min_samples_split' : range(5,10),
                        'decisiontreeregressor__min_samples_leaf' : range(5,10)}

grid_model = GridSearchCV(model_pipe, cv=5, param_grid={}, n_jobs=-1)
grid_model.fit(X_train, Y_train)

# 6. 평가
best_model = grid_model.best_estimator_

Y_train_pred = best_model.predict(X_train)
Y_test_pred = best_model.predict(X_test)

print(f'Y_train_pred : {Y_train_pred}\n')
print(f'Y_test_pred : {Y_test_pred}\n')
# 평가
print('학습능력평가')
print(classification_report(Y_train, Y_train_pred))
print('일반화능력평가')
print(classification_report(Y_test, Y_test_pred))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:972: UserWarning: One or more of the test scores are non-finite: [nan]
#   category=UserWarning,
# Y_train_pred : ['1만원대' '1만원대' '1만원대' ... '1만원대' '1만원대' '1만원대']
#
# Y_test_pred : ['10만원대' '1만원대' '1만원대' ... '1만원대' '1만원대' '1만원대']
#
# 학습능력평가
#               precision    recall  f1-score   support
#
#        10만원대       0.79      0.49      0.61      1256
#         1만원대       0.92      0.98      0.95      7983
#
#     accuracy                           0.91      9239
#    macro avg       0.86      0.74      0.78      9239
# weighted avg       0.91      0.91      0.91      9239
#
# 일반화능력평가
#               precision    recall  f1-score   support
#
#        10만원대       0.76      0.52      0.62       396
#         1만원대       0.93      0.98      0.95      2684
#
#     accuracy                           0.92      3080
#    macro avg       0.85      0.75      0.79      3080
# weighted avg       0.91      0.92      0.91      3080

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
# from xgboost import XGBClassifier
# 모델 선언 예시
# model = XGBClassifier(n_estimators=500, learning_rate=0.2, max_depth=4, random_state = 32)


model_pipe = make_pipeline(preprocessing_pipe, RandomForestClassifier())

hyperparameter_list = {}

grid_model = GridSearchCV(model_pipe, cv=5, param_grid={}, n_jobs=-1)
grid_model.fit(X_train, Y_train)

# 6. 평가
best_model = grid_model.best_estimator_

Y_train_pred = best_model.predict(X_train)
Y_test_pred = best_model.predict(X_test)

print(f'Y_train_pred : {Y_train_pred}\n')
print(f'Y_test_pred : {Y_test_pred}\n')
# 평가
print('학습능력평가')
print(classification_report(Y_train, Y_train_pred))
print('일반화능력평가')
print(classification_report(Y_test, Y_test_pred))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:972: UserWarning: One or more of the test scores are non-finite: [nan]
#   category=UserWarning,
# Y_train_pred : ['1만원대' '1만원대' '1만원대' ... '1만원대' '1만원대' '1만원대']
#
# Y_test_pred : ['10만원대' '1만원대' '1만원대' ... '1만원대' '1만원대' '1만원대']
#
# 학습능력평가
#               precision    recall  f1-score   support
#
#        10만원대       1.00      1.00      1.00      1256
#         1만원대       1.00      1.00      1.00      7983
#
#     accuracy                           1.00      9239
#    macro avg       1.00      1.00      1.00      9239
# weighted avg       1.00      1.00      1.00      9239
#
# 일반화능력평가
#               precision    recall  f1-score   support
#
#        10만원대       0.95      0.89      0.92       396
#         1만원대       0.98      0.99      0.99      2684
#
#     accuracy                           0.98      3080
#    macro avg       0.97      0.94      0.95      3080
# weighted avg       0.98      0.98      0.98      3080

# %% [markdown]
# ## K-최근접

# %%
model_pipe = make_pipeline(preprocessing_pipe, KNeighborsClassifier(n_neighbors = 7))

hyperparameter_list = {}

grid_model = GridSearchCV(model_pipe, cv=5, param_grid={}, n_jobs=-1)
grid_model.fit(X_train, Y_train)

# 6. 평가
best_model = grid_model.best_estimator_

Y_train_pred = best_model.predict(X_train)
Y_test_pred = best_model.predict(X_test)

print(f'Y_train_pred : {Y_train_pred}\n')
print(f'Y_test_pred : {Y_test_pred}\n')
# 평가
print('학습능력평가')
print(classification_report(Y_train, Y_train_pred))
print('일반화능력평가')
print(classification_report(Y_test, Y_test_pred))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_search.py:972: UserWarning: One or more of the test scores are non-finite: [nan]
#   category=UserWarning,
# Y_train_pred : ['1만원대' '1만원대' '1만원대' ... '1만원대' '1만원대' '1만원대']
#
# Y_test_pred : ['1만원대' '1만원대' '1만원대' ... '1만원대' '1만원대' '1만원대']
#
# 학습능력평가
#               precision    recall  f1-score   support
#
#        10만원대       0.88      0.65      0.75      1256
#         1만원대       0.95      0.99      0.97      7983
#
#     accuracy                           0.94      9239
#    macro avg       0.91      0.82      0.86      9239
# weighted avg       0.94      0.94      0.94      9239
#
# 일반화능력평가
#               precision    recall  f1-score   support
#
#        10만원대       0.80      0.55      0.65       396
#         1만원대       0.94      0.98      0.96      2684
#
#     accuracy                           0.92      3080
#    macro avg       0.87      0.77      0.81      3080
# weighted avg       0.92      0.92      0.92      3080

# %% [markdown]
# # PSB

# %%
df3.columns.tolist
# Out:
# <bound method IndexOpsMixin.tolist of Index(['ID', '나이', '사용가능 적립금', '성별', '주소(동/읍/면)', '최종접속일', '최종주문일', '유입경로',
#        '유입기기', '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트',
#        '배송번호', '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가_x', '품목번호', '#', '공급사', '과세/면세', '담기', '매입가',
#        '상품명(기본)', '상품코드', '재입고알림', '제조사', '카테고리', '판매가_y', '품절여부', '후기', '연령대',
#        '주문일시_dt', '주문일시_년', '주문일시_월', '주문일시_일', '주문일시_분기', '배송시작일_dt',
#        '배송완료일_dt', '배송시간', '시도', '가격대'],
#       dtype='object')>

# %%
sns.histplot(df3, x='연령대')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.distplot(df3['판매가_x'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df3_p_x = df3.pivot_table(index='사업자구분', values='판매가_x').reset_index()
df3_p_x
# Out:
#   사업자구분         판매가_x
# 0    개인  71209.519718
# 1   사업자  71037.262073
# 2   외국인  53900.000000

# %%
sns.barplot(data=df3_p_x, x='사업자구분', y='판매가_x')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51088 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50808 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.countplot(data = df3_m, x='주문일시_년', hue='연령대')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49884 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50672 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47161 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df3['배송시간'].value_counts()
# Out:
# 4 days     29910
# 6 days       413
# 0 days        33
# 2 days        26
# 1 days        12
# 8 days        11
# 7 days        11
# 5 days        10
# 3 days         6
# 24 days        3
# 9 days         3
# 10 days        2
# 12 days        2
# 15 days        1
# Name: 배송시간, dtype: int64

# %%
df3_c = df3[['나이', '사용가능 적립금', '성별', '최종주문일', '유입경로', '유입기기', '사업자구분', '회원구분', '결제수단', '교환구분', '배송비 정보', '사용한 적립금액', '상품구매금액', '상품번호', '상품별 추가할인금액', '수량', '주문 시 회원등급', '주문경로', '카드사', '쿠폰 할인금액', '판매가_x', '공급사', '과세/면세', '상품명(기본)', '재입고알림', '제조사', '카테고리', '품절여부', '후기', '연령대', '시도', '주문일시_dt', '배송시간']]

# %%
df3.corr()
# Out:
#                   나이  사용가능 적립금      공급원가  네이버 포인트  사용한 적립금액    상품구매금액  \
# 나이          1.000000 -0.006277  0.036779      NaN  0.057030  0.065242
# 사용가능 적립금   -0.006277  1.000000  0.039945      NaN  0.042835  0.094429
# 공급원가        0.036779  0.039945  1.000000      NaN  0.002928  0.531405
# 네이버 포인트          NaN       NaN       NaN      NaN       NaN       NaN
# 사용한 적립금액    0.057030  0.042835  0.002928      NaN  1.000000  0.062543
# 상품구매금액      0.065242  0.094429  0.531405      NaN  0.062543  1.000000
# 상품번호       -0.043025  0.059079 -0.186826      NaN  0.029110 -0.072301
# 상품별 추가할인금액  0.070744  0.056380  0.261154      NaN  0.030452  0.667072
# 수량          0.041795  0.081467 -0.091180      NaN  0.067805  0.704576
# 쿠폰 할인금액     0.044487  0.066987  0.001461      NaN -0.028631  0.017153
# 판매가_x       0.043877  0.042973  0.947346      NaN  0.005689  0.565426
# 품목번호       -0.121563  0.031511 -0.036290      NaN  0.028316 -0.076361
# #           0.044256 -0.062290  0.216417      NaN -0.032628  0.077112
# 담기         -0.051696  0.055349 -0.161295      NaN  0.035647 -0.000609
# 매입가         0.033161  0.037705  0.971371      NaN  0.005430  0.516279
# 상품코드       -0.043025  0.059079 -0.186826      NaN  0.029110 -0.072301
# 판매가_y       0.034749  0.042605  0.974867      NaN  0.006876  0.527813
# 후기         -0.052556  0.042291 -0.066890      NaN  0.021624  0.035761
# 주문일시_년     -0.105937  0.039019 -0.032493      NaN  0.021640 -0.067451
# 주문일시_월      0.016452 -0.021476  0.023676      NaN -0.002402  0.061802
# 주문일시_일     -0.011322 -0.000012  0.003421      NaN -0.004129 -0.008227
# 주문일시_분기     0.015708 -0.024050  0.023039      NaN -0.007202  0.068294
#
#                 상품번호  상품별 추가할인금액        수량   쿠폰 할인금액     판매가_x      품목번호  \
# 나이         -0.043025    0.070744  0.041795  0.044487  0.043877 -0.121563
# 사용가능 적립금    0.059079    0.056380  0.081467  0.066987  0.042973  0.031511
# 공급원가       -0.186826    0.261154 -0.091180  0.001461  0.947346 -0.036290
# 네이버 포인트          NaN         NaN       NaN       NaN       NaN       NaN
# 사용한 적립금액    0.029110    0.030452  0.067805 -0.028631  0.005689  0.028316
# 상품구매금액     -0.072301    0.667072  0.704576  0.017153  0.565426 -0.076361
# 상품번호        1.000000   -0.062479  0.070127  0.019368 -0.176448  0.339492
# 상품별 추가할인금액 -0.062479    1.000000  0.440826  0.016723  0.417300 -0.409474
# 수량          0.070127    0.440826  1.000000  0.015632 -0.089573  0.029214
# 쿠폰 할인금액     0.019368    0.016723  0.015632  1.000000  0.005625 -0.041973
# 판매가_x      -0.176448    0.417300 -0.089573  0.005625  1.000000 -0.138688
# 품목번호        0.339492   -0.409474  0.029214 -0.041973 -0.138688  1.000000
# #          -0.981217    0.067354 -0.088507 -0.023511  0.205673 -0.350819
# 담기          0.327928    0.018228  0.113979  0.003971 -0.150923  0.191506
# 매입가        -0.149041    0.257892 -0.086517  0.001455  0.918578 -0.030023
# 상품코드        1.000000   -0.062479  0.070127  0.019368 -0.176448  0.339492
# 판매가_y      -0.134807    0.258563 -0.078196  0.001503  0.927761 -0.023178
# 후기         -0.033812    0.045732  0.088101 -0.005150 -0.069708  0.065471
# 주문일시_년      0.315117   -0.356282  0.023414 -0.034391 -0.125116  0.871148
# 주문일시_월     -0.102006    0.279067 -0.005542 -0.007396  0.104840 -0.346140
# 주문일시_일     -0.009086   -0.033386 -0.015771  0.007522  0.004373  0.040301
# 주문일시_분기    -0.102932    0.306620  0.000100 -0.006920  0.109932 -0.349563
#
#                    #        담기       매입가      상품코드     판매가_y        후기  \
# 나이          0.044256 -0.051696  0.033161 -0.043025  0.034749 -0.052556
# 사용가능 적립금   -0.062290  0.055349  0.037705  0.059079  0.042605  0.042291
# 공급원가        0.216417 -0.161295  0.971371 -0.186826  0.974867 -0.066890
# 네이버 포인트          NaN       NaN       NaN       NaN       NaN       NaN
# 사용한 적립금액   -0.032628  0.035647  0.005430  0.029110  0.006876  0.021624
# 상품구매금액      0.077112 -0.000609  0.516279 -0.072301  0.527813  0.035761
# 상품번호       -0.981217  0.327928 -0.149041  1.000000 -0.134807 -0.033812
# 상품별 추가할인금액  0.067354  0.018228  0.257892 -0.062479  0.258563  0.045732
# 수량         -0.088507  0.113979 -0.086517  0.070127 -0.078196  0.088101
# 쿠폰 할인금액    -0.023511  0.003971  0.001455  0.019368  0.001503 -0.005150
# 판매가_x       0.205673 -0.150923  0.918578 -0.176448  0.927761 -0.069708
# 품목번호       -0.350819  0.191506 -0.030023  0.339492 -0.023178  0.065471
# #           1.000000 -0.383368  0.178368 -0.981217  0.157449 -0.023407
# 담기         -0.383368  1.000000 -0.140982  0.327928 -0.134898  0.785751
# 매입가         0.178368 -0.140982  1.000000 -0.149041  0.989837 -0.044717
# 상품코드       -0.981217  0.327928 -0.149041  1.000000 -0.134807 -0.033812
# 판매가_y       0.157449 -0.134898  0.989837 -0.134807  1.000000 -0.066199
# 후기         -0.023407  0.785751 -0.044717 -0.033812 -0.066199  1.000000
# 주문일시_년     -0.327845  0.195105 -0.026631  0.315117 -0.019702  0.072619
# 주문일시_월      0.118667 -0.101275  0.020001 -0.102006  0.015190 -0.046955
# 주문일시_일      0.011715 -0.013823  0.000966 -0.009086  0.000652 -0.005251
# 주문일시_분기     0.120156 -0.104872  0.019510 -0.102932  0.014424 -0.049160
#
#               주문일시_년    주문일시_월    주문일시_일   주문일시_분기
# 나이         -0.105937  0.016452 -0.011322  0.015708
# 사용가능 적립금    0.039019 -0.021476 -0.000012 -0.024050
# 공급원가       -0.032493  0.023676  0.003421  0.023039
# 네이버 포인트          NaN       NaN       NaN       NaN
# 사용한 적립금액    0.021640 -0.002402 -0.004129 -0.007202
# 상품구매금액     -0.067451  0.061802 -0.008227  0.068294
# 상품번호        0.315117 -0.102006 -0.009086 -0.102932
# 상품별 추가할인금액 -0.356282  0.279067 -0.033386  0.306620
# 수량          0.023414 -0.005542 -0.015771  0.000100
# 쿠폰 할인금액    -0.034391 -0.007396  0.007522 -0.006920
# 판매가_x      -0.125116  0.104840  0.004373  0.109932
# 품목번호        0.871148 -0.346140  0.040301 -0.349563
# #          -0.327845  0.118667  0.011715  0.120156
# 담기          0.195105 -0.101275 -0.013823 -0.104872
# 매입가        -0.026631  0.020001  0.000966  0.019510
# 상품코드        0.315117 -0.102006 -0.009086 -0.102932
# 판매가_y      -0.019702  0.015190  0.000652  0.014424
# 후기          0.072619 -0.046955 -0.005251 -0.049160
# 주문일시_년      1.000000 -0.715676 -0.015647 -0.703300
# 주문일시_월     -0.715676  1.000000 -0.006802  0.974109
# 주문일시_일     -0.015647 -0.006802  1.000000  0.000330
# 주문일시_분기    -0.703300  0.974109  0.000330  1.000000

# %%
df3_c.columns
# Out:
# Index(['나이', '사용가능 적립금', '성별', '최종주문일', '유입경로', '유입기기', '사업자구분', '회원구분',
#        '결제수단', '교환구분', '배송비 정보', '사용한 적립금액', '상품구매금액', '상품번호', '상품별 추가할인금액',
#        '수량', '주문 시 회원등급', '주문경로', '카드사', '쿠폰 할인금액', '판매가_x', '공급사', '과세/면세',
#        '상품명(기본)', '재입고알림', '제조사', '카테고리', '품절여부', '후기', '연령대', '시도', '주문일시_dt',
#        '배송시간'],
#       dtype='object')

# %%
sns.heatmap(df3_c.corr(), square=True, annot=True, cmap=plt.cm.viridis, linewidths=0.01, linecolor='white')
plt.figure(figsize=(10,10))
plt.gcf().set_size_inches(15, 8)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47549 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48264 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54840 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54624 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54256 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45208 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 45733 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47549 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50529 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54408 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47588 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48264 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54840 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 52628 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54624 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 53216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54256 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54032 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54980 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## RFM분석

# %% [markdown]
# # 새 섹션

# %%
# Recency : 얼마나 최근에 구매했는가
# Frequency : 얼마나 자주 구매했는가
# Monetary : 얼마나 많은 금액을 지출했는가

# %%
df3.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '주소(동/읍/면)', '최종접속일', '최종주문일', '유입경로',
#        '유입기기', '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트',
#        '배송번호', '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가_x', '품목번호', '#', '공급사', '과세/면세', '담기', '매입가',
#        '상품명(기본)', '상품코드', '재입고알림', '제조사', '카테고리', '판매가_y', '품절여부', '후기', '연령대',
#        '주문일시_dt', '주문일시_년', '주문일시_월', '주문일시_일', '주문일시_분기', '배송시작일_dt',
#        '배송완료일_dt', '배송시간', '시도', '가격대'],
#       dtype='object')

# %%
# Recency : 얼마나 최근에 구매했는가
df3.pivot_table(index=['주문일시_dt', 'ID'], values='판매가_y', aggfunc='sum').reset_index().sort_values(by=['주문일시_dt', '판매가_y'], ascending = False)
# Out:
#          주문일시_dt          ID   판매가_y
# 19011 2019-06-19   aaok02044  113300
# 19010 2019-06-04       pik99   61900
# 19009 2019-06-02      zagm10  177370
# 18999 2019-05-31      pp1526  392510
# 18972 2019-05-31  53100435@n  177540
# ...          ...         ...     ...
# 5     2017-02-13   gms112233   48500
# 3     2017-02-09       tokio  190970
# 2     2017-02-02  91559380@n   75820
# 1     2017-01-18     kim0750   78270
# 0     2017-01-01     cgh1385   64070
#
# [19012 rows x 3 columns]

# %%
df3.columns
# Out:
# Index(['ID', '나이', '사용가능 적립금', '성별', '주소(동/읍/면)', '최종접속일', '최종주문일', '유입경로',
#        '유입기기', '회원 가입일', '사업자구분', '회원구분', '결제수단', '공급원가', '교환구분', '네이버 포인트',
#        '배송번호', '배송비 정보', '배송시작일', '배송완료일', '사용한 적립금액', '상품구매금액', '상품명', '상품번호',
#        '상품별 추가할인금액', '수량', '수령인 주소', '주문 시 회원등급', '주문경로', '주문번호', '주문일시',
#        '카드사', '쿠폰 할인금액', '판매가_x', '품목번호', '#', '공급사', '과세/면세', '담기', '매입가',
#        '상품명(기본)', '상품코드', '재입고알림', '제조사', '카테고리', '판매가_y', '품절여부', '후기', '연령대',
#        '주문일시_dt', '주문일시_년', '주문일시_월', '주문일시_일', '주문일시_분기', '배송시작일_dt',
#        '배송완료일_dt', '배송시간', '시도', '가격대'],
#       dtype='object')

# %%
df3['연령대']
# Out:
# 0        50대
# 1        40대
# 2        40대
# 3        30대
# 4        30대
#         ...
# 30710    30대
# 30712    40대
# 30713    20대
# 30714    40대
# 30716    30대
# Name: 연령대, Length: 30443, dtype: object

# %%
df3[df3['연령대'] == '40대']
# Out:
#                ID  나이  사용가능 적립금  성별                   주소(동/읍/면)  \
# 1         ywca897  40     20440  남자    서울특별시 송파구 양재대로 897 (가락동)
# 2         ywca897  40     20440  남자    서울특별시 송파구 양재대로 897 (가락동)
# 8       6171754@n  48         0  남자  서울특별시 강남구 헌릉로571길 13 (세곡동)
# 11       makeupat  44         0  남자         서울특별시 광진구 구의동 220-9
# 12       noble602  44      2500  남자      경기도 포천시 소흘읍 호국로 308-11
# ...           ...  ..       ...  ..                         ...
# 30703   agape0828  46      1700  남자   서울특별시 노원구 상계로9가길 29 (상계동)
# 30705      nic003  42         0  남자         경상남도 양산시 물금읍 화합길 31
# 30708  luxury2007  46       600  남자              서울특별시 동대문구 제기동
# 30712    cjsekgod  47         0  남자      강원도 정선군 화암면 소금강로 80-23
# 30714     cji3838  47      1000  남자       전라남도 고흥군 도양읍 우주항공로 39
#
#                      최종접속일                최종주문일     유입경로 유입기기      회원 가입일  \
# 1       2019-05-03 오후 2:15   2019-04-08 오후 5:59  인터넷기사광고   PC  2017-03-21
# 2       2019-05-03 오후 2:15   2019-04-08 오후 5:59  인터넷기사광고   PC  2017-03-21
# 8       2017-05-09 오후 7:40   2017-05-09 오후 7:50    블로그광고   PC  2017-05-09
# 11     2017-06-12 오후 12:33  2017-06-12 오후 12:44    SNS광고  모바일  2017-06-12
# 12     2019-05-22 오전 11:11  2019-05-22 오전 11:13    블로그광고   PC  2017-08-03
# ...                    ...                  ...      ...  ...         ...
# 30703  2019-04-03 오전 10:01  2019-04-03 오전 10:08    전단지광고  모바일  2019-04-02
# 30705   2019-05-13 오후 1:42   2019-04-11 오후 3:19    인터넷검색   PC  2019-04-04
# 30708   2019-04-23 오전 8:27   2019-04-23 오전 9:55    전단지광고   PC  2019-04-22
# 30712   2019-05-09 오후 6:27   2019-05-09 오후 6:32    블로그광고   PC  2019-05-09
# 30714  2019-05-20 오후 12:40  2019-05-20 오후 12:41    전단지광고   PC  2019-05-12
#
#       사업자구분  회원구분       결제수단     공급원가  교환구분  네이버 포인트                   배송번호  \
# 1       사업자  특별회원   쿠폰,무통장입금  51700.0  교환안함        0  D-20180910-0000584-00
# 2       사업자  특별회원   쿠폰,무통장입금  51700.0  교환안함        0  D-20181217-0000713-01
# 8        개인    일반      쿠폰,카드  51700.0  교환안함        0  D-20170509-0000052-01
# 11      사업자   사업자      무통장입금  51700.0  교환안함        0  D-20170612-0000025-00
# 12      사업자   사업자  적립금,무통장입금  51700.0  교환안함        0  D-20190124-0000279-00
# ...     ...   ...        ...      ...   ...      ...                    ...
# 30703    개인    일반         카드  62000.0  교환안함        0  D-20190403-0000195-01
# 30705   사업자   사업자     적립금,카드  11000.0  교환안함        0  D-20190411-0000798-00
# 30708   사업자    일반     적립금,카드  52800.0  교환안함        0  D-20190423-0000127-00
# 30712    개인    일반     적립금,카드  18480.0  교환안함        0  D-20190509-0001072-01
# 30714    개인    일반         카드   8800.0  교환안함        0  D-20190512-0000092-01
#
#       배송비 정보                배송시작일               배송완료일  사용한 적립금액  상품구매금액  \
# 1         무료   2018-09-12 오후 6:31  2018-09-14 오후 4:46         0   82170
# 2         무료   2018-12-19 오후 5:36  2018-12-23 오전 5:32         0   82170
# 8         무료  2017-05-10 오후 10:20  2017-05-18 오후 2:33         0   71000
# 11        무료   2017-06-13 오전 9:14  2017-06-19 오전 5:39         0   71000
# 12        무료   2019-01-24 오후 6:32  2019-01-28 오전 5:32      7150   82170
# ...      ...                  ...                 ...       ...     ...
# 30703     무료   2019-04-03 오후 6:35  2019-04-07 오전 5:32         0   83000
# 30705     무료   2019-04-15 오전 8:47  2019-04-19 오전 5:32      1000   18500
# 30708     무료   2019-04-23 오후 6:53  2019-04-27 오전 5:32      1000   69400
# 30712     무료   2019-05-10 오후 7:05  2019-05-14 오전 5:32      1000   56800
# 30714     무료   2019-05-14 오후 6:51  2019-05-18 오전 5:32         0   17000
#
#                                                    상품명    상품번호  상품별 추가할인금액  \
# 1      105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45.0       18100
# 2      105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45.0       18100
# 8      105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45.0        7100
# 11     105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45.0        7100
# 12     105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45.0       18100
# ...                                                ...     ...         ...
# 30703                            골드 500 172개 1set(2박스)  1416.0           0
# 30705                               세줄소스병 특대 10개(1BOX)  1480.0           0
# 30708                    PSP 수산물접시 흑색 27호 1,000개(1BOX)  1458.0           0
# 30712                                위생초장병 대 10개(1BOX)  1507.0           0
# 30714                               누드 케찹병 대 10개(1BOX)  1462.0           0
#
#        수량                      수령인 주소 주문 시 회원등급   주문경로              주문번호  \
# 1       1    서울특별시 송파구 양재대로 897 (가락동)      특별회원  PC쇼핑몰  20180910-0000584
# 2       1    서울특별시 송파구 양재대로 897 (가락동)      특별회원  PC쇼핑몰  20181217-0000713
# 8       1  서울특별시 강남구 헌릉로571길 13 (세곡동)        일반   모바일웹  20170509-0000052
# 11      1         서울특별시 광진구 구의동 220-9        일반   모바일웹  20170612-0000025
# 12      1      경기도 포천시 소흘읍 호국로 308-11       사업자  PC쇼핑몰  20190124-0000279
# ...    ..                         ...       ...    ...               ...
# 30703   1   서울특별시 노원구 상계로9가길 29 (상계동)        일반   모바일웹  20190403-0000195
# 30705   1         경상남도 양산시 물금읍 화합길 31       사업자  PC쇼핑몰  20190411-0000798
# 30708   1              서울특별시 동대문구 제기동        일반  PC쇼핑몰  20190423-0000127
# 30712   2      강원도 정선군 화암면 소금강로 80-23        일반  PC쇼핑몰  20190509-0001072
# 30714   1       전라남도 고흥군 도양읍 우주항공로 39        일반  PC쇼핑몰  20190512-0000092
#
#                       주문일시            카드사  쿠폰 할인금액  판매가_x   품목번호     #  \
# 1       2018-09-10 오후 3:29           카드아님    10050  82170  24318  1013
# 2       2018-12-17 오후 2:36           카드아님    16010  82170  40547  1013
# 8       2017-05-09 오후 7:50             비씨     3000  71000    286  1013
# 11     2017-06-12 오후 12:44           카드아님        0  71000    569  1013
# 12     2019-01-24 오후 12:31           카드아님        0  82170  48674  1013
# ...                    ...            ...      ...    ...    ...   ...
# 30703  2019-04-03 오전 10:08             삼성        0  83000  65473   654
# 30705   2019-04-11 오후 3:19             삼성        0  18500  67792   599
# 30708   2019-04-23 오전 9:55           하나SK        0  69400  70201   618
# 30712   2019-05-09 오후 6:32  신한(구.LG카드 포함)        0  28400  74771   584
# 30714  2019-05-12 오후 12:12  신한(구.LG카드 포함)        0  17000  75130   614
#
#            공급사 과세/면세  담기    매입가  \
# 1          패커스    과세  17  51700
# 2          패커스    과세  17  51700
# 8          패커스    과세  17  51700
# 11         패커스    과세  17  51700
# 12         패커스    과세  17  51700
# ...        ...   ...  ..    ...
# 30703      패커스    과세   0  62000
# 30705  다이찌롱스토어    과세   0  11000
# 30708      패커스    과세   1  52800
# 30712  다이찌롱스토어    과세   0  18480
# 30714  다이찌롱스토어    과세   0   8800
#
#                                                상품명(기본)  상품코드 재입고알림   제조사  \
# 1      105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45   사용함  자체제작
# 2      105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45   사용함  자체제작
# 8      105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45   사용함  자체제작
# 11     105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45   사용함  자체제작
# 12     105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45   사용함  자체제작
# ...                                                ...   ...   ...   ...
# 30703                            골드 500 172개 1set(2박스)  1416   사용함  자체제작
# 30705                               세줄소스병 특대 10개(1BOX)  1480   사용함  자체제작
# 30708                     스티로폼 수산물접시 흑색 27호 1,000개 1박스  1458   사용함  자체제작
# 30712                                위생초장병 대 10개(1BOX)  1507   사용함  자체제작
# 30714                               누드 케찹병 대 10개(1BOX)  1462   사용함  자체제작
#
#                                                     카테고리  판매가_y 품절여부  후기  연령대  \
# 1      039 : 중식 용기\n039003 : 중식 용기 > 소스/국/밥용기\n040 : ...  64070   정상  30  40대
# 2      039 : 중식 용기\n039003 : 중식 용기 > 소스/국/밥용기\n040 : ...  64070   정상  30  40대
# 8      039 : 중식 용기\n039003 : 중식 용기 > 소스/국/밥용기\n040 : ...  64070   정상  30  40대
# 11     039 : 중식 용기\n039003 : 중식 용기 > 소스/국/밥용기\n040 : ...  64070   정상  30  40대
# 12     039 : 중식 용기\n039003 : 중식 용기 > 소스/국/밥용기\n040 : ...  64070   정상  30  40대
# ...                                                  ...    ...  ...  ..  ...
# 30703  043 : 베이커리/카페 용기\n043004 : 베이커리/카페 용기 > 생수/쥬스/...  83000   정상   0  40대
# 30705  046 : 주방용품/소모품\n046007 : 주방용품/소모품 > 주방용품\n0460...  18500   정상   0  40대
# 30708  044 : 농수산물 용기\n044001 : 농수산물 용기 > 스트로폼용기\n061 ...  69400   정상   0  40대
# 30712  046 : 주방용품/소모품\n046007 : 주방용품/소모품 > 주방용품\n0460...  28400   정상   0  40대
# 30714  046 : 주방용품/소모품\n046007 : 주방용품/소모품 > 주방용품\n0460...  17000   정상   0  40대
#
#          주문일시_dt  주문일시_년  주문일시_월  주문일시_일  주문일시_분기   배송시작일_dt   배송완료일_dt  \
# 1     2018-09-10    2018       9      10        3 2018-09-12 2018-09-14
# 2     2018-12-17    2018      12      17        4 2018-12-19 2018-12-23
# 8     2017-05-09    2017       5       9        2 2017-05-10 2017-05-18
# 11    2017-06-12    2017       6      12        2 2017-06-13 2017-06-19
# 12    2019-01-24    2019       1      24        1 2019-01-24 2019-01-28
# ...          ...     ...     ...     ...      ...        ...        ...
# 30703 2019-04-03    2019       4       3        2 2019-04-03 2019-04-07
# 30705 2019-04-11    2019       4      11        2 2019-04-15 2019-04-19
# 30708 2019-04-23    2019       4      23        2 2019-04-23 2019-04-27
# 30712 2019-05-09    2019       5       9        2 2019-05-10 2019-05-14
# 30714 2019-05-12    2019       5      12        2 2019-05-14 2019-05-18
#
#         배송시간     시도   가격대
# 1     2 days  서울특별시  1만원대
# 2     4 days  서울특별시  1만원대
# 8     8 days  서울특별시  1만원대
# 11    6 days  서울특별시  1만원대
# 12    4 days    경기도  1만원대
# ...      ...    ...   ...
# 30703 4 days  서울특별시  1만원대
# 30705 4 days   경상남도  1만원대
# 30708 4 days  서울특별시  1만원대
# 30712 4 days    강원도  1만원대
# 30714 4 days   전라남도  1만원대
#
# [16470 rows x 59 columns]

# %%
# Frequency : 얼마나 자주 구매했는가
df3[df3['주문일시_dt']== pd.to_datetime('2019-01-28')].pivot_table(index='연령대', values='판매가_y', aggfunc='count').reset_index().sort_values(by='판매가_y', ascending=False).head()
# Out:
#    연령대  판매가_y
# 2  40대    178
# 1  30대     58
# 0  20대     52
# 4  70대      4
# 3  60대      2

# %%
# Monetary : 얼마나 많은 금액을 지출했는가
df3.pivot_table(index='연령대', values='판매가_y', aggfunc='sum').reset_index().sort_values(by='판매가_y', ascending=False).head()
# Out:
#    연령대       판매가_y
# 2  40대  1032618670
# 1  30대   437468750
# 0  20대   340137570
# 3  50대    84756550
# 4  60대    15066780

# %%
df
# Out:
#                  ID  나이  사용가능 적립금  성별                최종접속일  \
# 0           cgh1385  53         0  남자  2017-01-02 오후 12:32
# 1            pjkl77  28         0  남자  2017-02-26 오후 10:52
# 2            pjkl77  28         0  남자  2017-02-26 오후 10:52
# 3            pjkl77  28         0  남자  2017-02-26 오후 10:52
# 4           bear011  40     21908  남자   2018-12-19 오후 1:26
# ...             ...  ..       ...  ..                  ...
# 43520  1094746791@k  47      1200  남자   2019-05-31 오후 5:00
# 43521    51775030@n  45       600  남자   2019-05-31 오후 2:41
# 43522        pp1730  31      1000  남자   2019-05-31 오후 4:38
# 43523     aaok02044  46      1000  남자  2019-06-19 오전 10:59
# 43524     aaok02044  46      1000  남자  2019-06-19 오전 10:59
#
#                      최종주문일   유입경로 유입기기      회원 가입일 사업자구분     회원구분  \
# 0       2017-01-01 오후 3:38  블로그광고  모바일  2017-01-01    개인       일반
# 1      2017-02-26 오후 10:55  이메일광고   PC  2017-01-14   사업자      사업자
# 2      2017-02-26 오후 10:55  이메일광고   PC  2017-01-14   사업자      사업자
# 3      2017-02-26 오후 10:55  이메일광고   PC  2017-01-14   사업자      사업자
# 4       2018-12-19 오후 1:29  SNS광고  모바일  2017-01-17   사업자      사업자
# ...                    ...    ...  ...         ...   ...      ...
# 43520   2019-05-31 오후 4:58  SNS광고  모바일  2019-05-31    개인       일반
# 43521   2019-05-31 오후 3:17  SNS광고  모바일  2019-05-31    개인       일반
# 43522   2019-05-31 오후 4:30  유튜브광고   PC  2019-05-31    개인  전화주문 고객
# 43523  2019-06-19 오전 11:18  인터넷검색  모바일  2019-06-19   사업자       일반
# 43524  2019-06-19 오전 11:18  인터넷검색  모바일  2019-06-19   사업자       일반
#
#                  결제수단     공급원가  교환구분  네이버 포인트                   배송번호 배송비 정보  \
# 0               무통장입금  51700.0  교환안함        0  D-20170101-0000015-00     선불
# 1               쿠폰,카드   6200.0  교환안함        0  D-20170115-0000013-00     선불
# 2               쿠폰,카드   6200.0  교환안함        0  D-20170123-0000021-00     선불
# 3            페이나우(카드)   6200.0  교환안함        0  D-20170226-0000015-00     선불
# 4               무통장입금  51040.0  교환안함        0  D-20180512-0000093-00     무료
# ...               ...      ...   ...      ...                    ...    ...
# 43520              카드  92400.0  교환안함        0  D-20190531-0000551-01     무료
# 43521          적립금,카드  47850.0  교환안함        0  D-20190531-0000467-00     무료
# 43522           무통장입금  42900.0  교환안함        0  D-20190531-0000541-00     무료
# 43523  페이나우(실시간 계좌이체)  34650.0  교환안함        0  D-20190619-0000037-00     무료
# 43524  페이나우(실시간 계좌이체)  42900.0  교환안함        0  D-20190619-0000053-00     무료
#
#                      배송시작일               배송완료일  사용한 적립금액  상품구매금액  \
# 0       2017-01-17 오전 8:26  2017-01-17 오전 8:26         0   66500
# 1       2017-01-19 오전 8:56  2017-01-19 오후 7:51         0   17000
# 2       2017-01-23 오후 3:26  2017-01-24 오후 6:00         0   17000
# 3       2017-02-27 오후 3:26  2017-03-01 오전 9:45         0   17000
# 4      2018-05-18 오전 11:07  2018-05-22 오전 5:32         0   75390
# ...                    ...                 ...       ...     ...
# 43520   2019-06-03 오후 6:08  2019-06-07 오전 5:32         0  132360
# 43521   2019-06-03 오후 6:08  2019-06-07 오전 5:32      1000   61900
# 43522   2019-06-03 오후 6:08  2019-06-07 오전 5:32         0   55870
# 43523   2019-06-20 오후 5:32  2019-06-24 오전 5:32         0   52400
# 43524   2019-06-20 오후 5:32  2019-06-24 오전 5:32         0   60900
#
#                                                    상품명    상품번호  상품별 추가할인금액  \
# 0      105파이 다용도컵 세트 5호 대 370ml 백색 PS 1,000개 1set(2박스)    45.0           0
# 1               소량 105파이 다용도컵 세트 5호 대 370ml 투명 PS 100개    67.0           0
# 2               소량 105파이 다용도컵 세트 5호 대 370ml 투명 PS 100개    67.0           0
# 3               소량 105파이 다용도컵 세트 5호 대 370ml 투명 PS 100개    67.0           0
# 4                          실링용기 2호 백색 1,150ml 800개 1박스   966.0       15000
# ...                                                ...     ...         ...
# 43520                   물김치용기 투명 100개 1set(2박스/직사각 5L)  1353.0           0
# 43521                       195파이 탕용기 대 300개 1set(2박스)   608.0           0
# 43522    70파이 다용도컵 세트 1호 소 70ml 백색 PS 3,000개 1set(2박스)    38.0           0
# 43523                           210파이 중화면용기 소 300개 1박스  1373.0           0
# 43524                           210파이 중화면용기 중 300개 1박스  1374.0           0
#
#        수량                         수령인 주소 주문 시 회원등급   주문경로              주문번호  \
# 0       1  전라북도 전주시 덕진구 동부대로 879 (호성동1가)        일반   모바일웹  20170101-0000015
# 1       1     전라북도 전주시 완산구 효자동3가 1676-13        일반  PC쇼핑몰  20170115-0000013
# 2       1     전라북도 전주시 완산구 효자동3가 1676-13       사업자  PC쇼핑몰  20170123-0000021
# 3       1     전라북도 전주시 완산구 효자동3가 1676-13       사업자  PC쇼핑몰  20170226-0000015
# 4       1       경기도 부천시 원미구 상일로 126 (상동)       사업자  PC쇼핑몰  20180512-0000093
# ...    ..                            ...       ...    ...               ...
# 43520   1      충청남도 공주시 한적2길 64-13 (금흥동)        일반   모바일웹  20190531-0000551
# 43521   1          대전광역시 서구 도솔로 41 (도마동)        일반   모바일웹  20190531-0000467
# 43522   1     경기도 의정부시 동일로454번길 40 (신곡동)   전화주문 고객  PC쇼핑몰  20190531-0000541
# 43523   1    경상남도 창원시 의창구 북면 무동로267번길 10        일반   모바일웹  20190619-0000037
# 43524   1    경상남도 창원시 의창구 북면 무동로267번길 10        일반   모바일웹  20190619-0000053
#
#                       주문일시      카드사  쿠폰 할인금액     판매가   품목번호 결제수단_cut  \
# 0       2017-01-01 오후 3:38     카드아님        0   66500      4    무통장입금
# 1       2017-01-15 오전 1:24  NH (농협)     5000   17000      9       카드
# 2      2017-01-23 오전 12:35  NH (농협)     3000   17000     19       카드
# 3      2017-02-26 오후 10:55  NH (농협)        0   17000     67       카드
# 4       2018-05-12 오후 2:10     카드아님        0   75390   9588    무통장입금
# ...                    ...      ...      ...     ...    ...      ...
# 43520   2019-05-31 오후 4:58  NH (농협)        0  132360  79777       카드
# 43521   2019-05-31 오후 3:17  NH (농협)        0   61900  79743       카드
# 43522   2019-05-31 오후 4:30     카드아님        0   55870  79774    무통장입금
# 43523  2019-06-19 오전 11:14     카드아님        0   52400  79829       기타
# 43524  2019-06-19 오전 11:18     카드아님        0   60900  79832       기타
#
#                                   주소     시도    주문일시_dt  주문일시_년  주문일시_월  \
# 0      전라북도 전주시 덕진구 동부대로 879 (호성동1가)   전라북도 2017-01-01    2017       1
# 1         전라북도 전주시 완산구 효자동3가 1676-13   전라북도 2017-01-15    2017       1
# 2         전라북도 전주시 완산구 효자동3가 1676-13   전라북도 2017-01-23    2017       1
# 3         전라북도 전주시 완산구 효자동3가 1676-13   전라북도 2017-02-26    2017       2
# 4           경기도 부천시 원미구 상일로 126 (상동)    경기도 2018-05-12    2018       5
# ...                              ...    ...        ...     ...     ...
# 43520      충청남도 공주시 한적2길 64-13 (금흥동)   충청남도 2019-05-31    2019       5
# 43521          대전광역시 서구 도솔로 41 (도마동)  대전광역시 2019-05-31    2019       5
# 43522     경기도 의정부시 동일로454번길 40 (신곡동)    경기도 2019-05-31    2019       5
# 43523    경상남도 창원시 의창구 북면 무동로267번길 10   경상남도 2019-06-19    2019       6
# 43524    경상남도 창원시 의창구 북면 무동로267번길 10   경상남도 2019-06-19    2019       6
#
#        주문일시_일  주문일시_분기    연령대
# 0           1        1    50대
# 1          15        1  20대후반
# 2          23        1  20대후반
# 3          26        1  20대후반
# 4          12        2    40대
# ...       ...      ...    ...
# 43520      31        2    40대
# 43521      31        2    40대
# 43522      31        2  30대초반
# 43523      19        2    40대
# 43524      19        2    40대
#
# [43479 rows x 43 columns]

# %%
df3_sum = df3.pivot_table(index='ID', values='판매가_x', aggfunc='sum').reset_index()

# %%
df3_count = df3.pivot_table(index='ID', values='판매가_x', aggfunc='count').reset_index()

# %%
df3_rf = pd.merge(df3_sum, df3_count, on='ID', how='inner')

# %%
df3_rf.columns
# Out:
# Index(['ID', '판매가_x_x', '판매가_x_y'], dtype='object')

# %%
df3_rf['판매가_x_x'].sum()
# Out:
# 2165256590

# %%
df3_rf['m'] = 2165256590

# %%
df3_rf['m2'] = df3_rf['판매가_x_x']/df3_rf['m']

# %%
df3_rf
# Out:
#                 ID  판매가_x_x  판매가_x_y           m        m2
# 0     1003409866@k  2281740       35  2165256590  0.001054
# 1      100381931@n    41730        3  2165256590  0.000019
# 2     1004498382@k    76400        1  2165256590  0.000035
# 3     1004547839@k   180400        2  2165256590  0.000083
# 4     1004714862@k   108110        2  2165256590  0.000050
# ...            ...      ...      ...         ...       ...
# 4615       zxvnm07    94380        1  2165256590  0.000044
# 4616        zxxz60   472520        8  2165256590  0.000218
# 4617      zzar2000  1347600       22  2165256590  0.000622
# 4618       zzbbwmf   166140        3  2165256590  0.000077
# 4619     zzzxkxk91    84700        1  2165256590  0.000039
#
# [4620 rows x 5 columns]

# %%
df3_rf.columns
# Out:
# Index(['ID', '판매가_x_x', '판매가_x_y', 'm', 'm2'], dtype='object')

# %%
df3_rf.rename(columns = {'판매가_x_x':'R', '판매가_x_y' : 'F', 'm2' : 'M'},inplace=True)

# %%
df3_rfm = df3_rf[['ID', 'R', 'F', 'M']]

# %%
df3_rfm
# Out:
#                 ID        R   F         M
# 0     1003409866@k  2281740  35  0.001054
# 1      100381931@n    41730   3  0.000019
# 2     1004498382@k    76400   1  0.000035
# 3     1004547839@k   180400   2  0.000083
# 4     1004714862@k   108110   2  0.000050
# ...            ...      ...  ..       ...
# 4615       zxvnm07    94380   1  0.000044
# 4616        zxxz60   472520   8  0.000218
# 4617      zzar2000  1347600  22  0.000622
# 4618       zzbbwmf   166140   3  0.000077
# 4619     zzzxkxk91    84700   1  0.000039
#
# [4620 rows x 4 columns]

# %%
df3_rfm.sort_values(by='M',ascending=False)
# Out:
#                ID         R    F         M
# 2131  mission1013  16657720  205  0.007693
# 662   776646558@k  15786750  194  0.007291
# 1117      cmp1220  12685920  163  0.005859
# 915          as12   9703390  133  0.004481
# 4477    wndjdqkqh   8945260  135  0.004131
# ...           ...       ...  ...       ...
# 2927       pp1472      9190    1  0.000004
# 648   760746334@k      9000    1  0.000004
# 3057       pp1600      8440    1  0.000004
# 3214        pp201         0    1  0.000000
# 3210        pp197         0    1  0.000000
#
# [4620 rows x 4 columns]
